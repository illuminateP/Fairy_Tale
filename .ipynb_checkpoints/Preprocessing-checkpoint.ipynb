# %%
import os
import json
import pandas as pd
import collections

# %%
import os, json
isbns = set()
for dirpath, _, filenames in os.walk('./datasets/Training'):
    for fn in filenames:
        if fn.lower().endswith('.json'):
            with open(os.path.join(dirpath, fn), encoding='utf-8-sig') as f:
                d = json.load(f)
            books = d if isinstance(d, list) else [d]
            for book in books:
                isbns.add(str(book.get('isbn','')).strip())
print(f"원본 폴더 기준 고유권수 : {len(isbns)}")  # 원본 폴더 기준 고유권수
# Out:
# 원본 폴더 기준 고유권수 : 1446

# %%
import os, json
isbns = set()
for dirpath, _, filenames in os.walk('./datasets/Validation'):
    for fn in filenames:
        if fn.lower().endswith('.json'):
            with open(os.path.join(dirpath, fn), encoding='utf-8-sig') as f:
                d = json.load(f)
            books = d if isinstance(d, list) else [d]
            for book in books:
                isbns.add(str(book.get('isbn','')).strip())
print(f"원본 폴더 기준 고유권수 : {len(isbns)}")  # 원본 폴더 기준 고유권수
# Out:
# 원본 폴더 기준 고유권수 : 286

# %%
root_dir = './datasets'

# %%
json_files = []
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        if filename.lower().endswith('.json'):
            json_files.append(os.path.join(dirpath, filename))

# %%
isbn_title_set = set()
isbn_meta_dict = {}

for filepath in json_files:
    try:
        with open(filepath, 'r', encoding='utf-8-sig') as f:
            data = json.load(f)
        if isinstance(data, list):  # 혹시 리스트형이면
            items = data
        else:
            items = [data]
        for book in items:
            isbn = str(book.get('isbn', '')).strip()
            title = book.get('title', '').strip()
            if isbn and title:
                isbn_title_set.add((isbn, title))
                # 메타만 남기기
                meta = {
                    "isbn": isbn,
                    "title": title,
                    "author": book.get('author', '').strip(),
                    "illustrator": book.get('illustrator', '').strip(),
                    "readAge": book.get('readAge', '').strip(),
                    "publishedYear": book.get('publishedYear', ''),
                    "publisher": book.get('publisher', '').strip(),
                    "classification": book.get('classification', '').strip()
                }
                isbn_meta_dict[isbn] = meta
    except Exception as e:
        print(f"Error: {filepath}, {e}")

# %% [markdown]
# ### csv

# %%
# 1. isbn + title csv
df_titles = pd.DataFrame(list(isbn_title_set), columns=['isbn', 'title']).sort_values('isbn')
df_titles.to_csv(os.path.join(root_dir, 'isbn_title_only.csv'), index=False, encoding='utf-8-sig')
print(f"1. isbn-title csv 저장 ({len(df_titles)} 행)")
# Out:
# 1. isbn-title csv 저장 (1732 행)

# %% [markdown]
# ### json

# %%
# 2. isbn별 메타데이터 json 파일
meta_dir = os.path.join(root_dir, 'isbn_meta')
os.makedirs(meta_dir, exist_ok=True)
for isbn, meta in isbn_meta_dict.items():
    with open(os.path.join(meta_dir, f"{isbn}.json"), 'w', encoding='utf-8-sig') as f:
        json.dump(meta, f, ensure_ascii=False, indent=2)
print(f"2. isbn별 메타 json 저장 ({len(isbn_meta_dict)} 파일)")
# Out:
# 2. isbn별 메타 json 저장 (1732 파일)

# %% [markdown]
# ### meta

# %%
# 3. 전체 통합 메타 json
all_meta_path = os.path.join(root_dir, 'all_isbn_meta.json')
with open(all_meta_path, 'w', encoding='utf-8-sig') as f:
    json.dump(list(isbn_meta_dict.values()), f, ensure_ascii=False, indent=2)
print(f"3. 전체 통합 메타 json 저장 ({len(isbn_meta_dict)}권)")
# Out:
# 3. 전체 통합 메타 json 저장 (1732권)

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ### Training

# %%
import os
import json
import shutil
import pandas as pd
from collections import defaultdict

# --- 경로 설정 ---
root_dir = './datasets/Training'
sublabel_dir = './datasets/Sublabel'
converted_root = './converted/training'
converted_sublabel = './converted/Sublabel'
json_dir = os.path.join(converted_root, 'json')
os.makedirs(json_dir, exist_ok=True)
os.makedirs(converted_sublabel, exist_ok=True)

# --- 1. isbn별 메타/질문 집계 ---
isbn_info = {}
isbn_explicit = defaultdict(bool)

json_files = []
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        if filename.lower().endswith('.json'):
            json_files.append(os.path.join(dirpath, filename))

for src_path in json_files:
    with open(src_path, 'r', encoding='utf-8-sig') as f:
        data = json.load(f)
    books = data if isinstance(data, list) else [data]
    for book in books:
        isbn = str(book.get('isbn', '')).strip()
        title = book.get('title', '').strip()
        if not isbn:
            continue
        # 메타 정보 최초 1회만 기록
        if isbn not in isbn_info:
            meta = {"isbn": isbn, "title": title}
            for key in ["author", "illustrator", "readAge", "publishedYear", "publisher", "classification"]:
                if key in book and book[key]:
                    meta[key] = str(book[key]).strip()
            isbn_info[isbn] = meta
        # 명시적 질문 있는지 체크
        for para in book.get('paragraphInfo', []):
            for qa in para.get('queAnsPairInfo', []):
                if '명시적' in qa.get('ansType', ''):
                    isbn_explicit[isbn] = True

isbn_all_set = set(isbn_info.keys())
isbn_explicit_set = set(isbn for isbn, flag in isbn_explicit.items() if flag)
isbn_removed_set = isbn_all_set - isbn_explicit_set

print(f"전체 isbn 고유권수: {len(isbn_all_set)}")
print(f"명시적 질문 1개 이상 있는 책 권수: {len(isbn_explicit_set)}")
print(f"명시적 질문 0개인 책 권수: {len(isbn_removed_set)}")

# --- 2. 변환 json/meta ---
meta_list = []
meta_dict = {}

for src_path in json_files:
    with open(src_path, 'r', encoding='utf-8-sig') as f:
        data = json.load(f)
    books = data if isinstance(data, list) else [data]
    new_books = []
    for book in books:
        isbn = str(book.get('isbn', '')).strip()
        if isbn not in isbn_explicit_set:
            continue
        # 명시적 질문만 남긴다
        book_copy = dict(book)
        new_paragraphs = []
        for para in book.get('paragraphInfo', []):
            new_para = dict(para)
            new_qapairs = []
            for qa in para.get('queAnsPairInfo', []):
                if '명시적' in qa.get('ansType', ''):
                    new_qapairs.append(qa)
            new_para['queAnsPairInfo'] = new_qapairs
            new_para['queAnsPairInfoCount'] = len(new_qapairs)
            new_paragraphs.append(new_para)
        book_copy['paragraphInfo'] = new_paragraphs
        new_books.append(book_copy)
    if new_books:
        rel_path = os.path.relpath(src_path, root_dir)
        save_path = os.path.join(converted_root, rel_path)
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        with open(save_path, 'w', encoding='utf-8-sig') as f:
            if isinstance(data, list):
                json.dump(new_books, f, ensure_ascii=False, indent=2)
            else:
                json.dump(new_books[0], f, ensure_ascii=False, indent=2)

for isbn in sorted(isbn_explicit_set):
    meta_dict[isbn] = isbn_info[isbn]
    meta_list.append(isbn_info[isbn])

# --- 3. Sublabel 복사(하위폴더 전체에서 isbn에 맞는 파일 찾기) ---
def find_sublabel_file(sublabel_dir, isbn):
    for dirpath, _, filenames in os.walk(sublabel_dir):
        for filename in filenames:
            if filename.endswith(f"{isbn}.json"):
                return os.path.join(dirpath, filename)
    return None

copy_ok, copy_fail = 0, 0
for isbn in isbn_explicit_set:
    src_full = find_sublabel_file(sublabel_dir, isbn)
    dst_full = os.path.join(converted_sublabel, f"{isbn}.json")
    if src_full and os.path.exists(src_full):
        shutil.copy2(src_full, dst_full)
        copy_ok += 1
    else:
        print(f"[Sublabel 없음] {isbn}")
        copy_fail += 1
print(f"Sublabel 복사: {copy_ok}개 성공, {copy_fail}개 실패")

# --- 4. 결과 저장 ---
meta_simple_path = os.path.join(json_dir, 'book_titles_by_isbn.json')
with open(meta_simple_path, 'w', encoding='utf-8-sig') as f:
    json.dump([{"isbn": m["isbn"], "title": m["title"]} for m in meta_list], f, ensure_ascii=False, indent=2)

meta_all_path = os.path.join(json_dir, 'book_meta_all.json')
with open(meta_all_path, 'w', encoding='utf-8-sig') as f:
    json.dump(meta_list, f, ensure_ascii=False, indent=2)

meta_books_dir = os.path.join(json_dir, 'books_by_isbn')
os.makedirs(meta_books_dir, exist_ok=True)
for isbn, meta in meta_dict.items():
    meta_path = os.path.join(meta_books_dir, f'{isbn}.json')
    with open(meta_path, 'w', encoding='utf-8-sig') as f:
        json.dump(meta, f, ensure_ascii=False, indent=2)

removed_path = os.path.join(json_dir, 'removed_books.csv')
pd.DataFrame([isbn_info[i] for i in sorted(isbn_removed_set)]).to_csv(removed_path, index=False, encoding='utf-8-sig')

print(f"[최종] 전체 고유 isbn: {len(isbn_all_set)}")
print(f"[최종] 명시적 질문 있는 책: {len(isbn_explicit_set)}")
print(f"[최종] 명시적 질문 없는 책: {len(isbn_removed_set)}")
print(f"모든 전처리/저장 완료!")
# Out:
# 전체 isbn 고유권수: 1446
# 명시적 질문 1개 이상 있는 책 권수: 1443
# 명시적 질문 0개인 책 권수: 3
# [Sublabel 없음] 9791159420214
# [Sublabel 없음] 9791186922972
# [Sublabel 없음] 9788961914314
# Sublabel 복사: 1440개 성공, 3개 실패
# [최종] 전체 고유 isbn: 1446
# [최종] 명시적 질문 있는 책: 1443
# [최종] 명시적 질문 없는 책: 3
# 모든 전처리/저장 완료!

# %% [markdown]
# ### Validation

# %%
import os
import json
import shutil
import pandas as pd
from collections import defaultdict

# --- 경로 설정 ---
root_dir = './datasets/Validation'
sublabel_dir = './datasets/Sublabel'
converted_root = './converted/validation'
converted_sublabel = './converted/Sublabel'
json_dir = os.path.join(converted_root, 'json')
os.makedirs(json_dir, exist_ok=True)
os.makedirs(converted_sublabel, exist_ok=True)

# --- 1. isbn별 메타/질문 집계 ---
isbn_info = {}
isbn_explicit = defaultdict(bool)

json_files = []
for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        if filename.lower().endswith('.json'):
            json_files.append(os.path.join(dirpath, filename))

for src_path in json_files:
    with open(src_path, 'r', encoding='utf-8-sig') as f:
        data = json.load(f)
    books = data if isinstance(data, list) else [data]
    for book in books:
        isbn = str(book.get('isbn', '')).strip()
        title = book.get('title', '').strip()
        if not isbn:
            continue
        # 메타 정보 최초 1회만 기록
        if isbn not in isbn_info:
            meta = {"isbn": isbn, "title": title}
            for key in ["author", "illustrator", "readAge", "publishedYear", "publisher", "classification"]:
                if key in book and book[key]:
                    meta[key] = str(book[key]).strip()
            isbn_info[isbn] = meta
        # 명시적 질문 있는지 체크
        for para in book.get('paragraphInfo', []):
            for qa in para.get('queAnsPairInfo', []):
                if '명시적' in qa.get('ansType', ''):
                    isbn_explicit[isbn] = True

isbn_all_set = set(isbn_info.keys())
isbn_explicit_set = set(isbn for isbn, flag in isbn_explicit.items() if flag)
isbn_removed_set = isbn_all_set - isbn_explicit_set

print(f"전체 isbn 고유권수: {len(isbn_all_set)}")
print(f"명시적 질문 1개 이상 있는 책 권수: {len(isbn_explicit_set)}")
print(f"명시적 질문 0개인 책 권수: {len(isbn_removed_set)}")

# --- 2. 변환 json/meta ---
meta_list = []
meta_dict = {}

for src_path in json_files:
    with open(src_path, 'r', encoding='utf-8-sig') as f:
        data = json.load(f)
    books = data if isinstance(data, list) else [data]
    new_books = []
    for book in books:
        isbn = str(book.get('isbn', '')).strip()
        if isbn not in isbn_explicit_set:
            continue
        # 명시적 질문만 남긴다
        book_copy = dict(book)
        new_paragraphs = []
        for para in book.get('paragraphInfo', []):
            new_para = dict(para)
            new_qapairs = []
            for qa in para.get('queAnsPairInfo', []):
                if '명시적' in qa.get('ansType', ''):
                    new_qapairs.append(qa)
            new_para['queAnsPairInfo'] = new_qapairs
            new_para['queAnsPairInfoCount'] = len(new_qapairs)
            new_paragraphs.append(new_para)
        book_copy['paragraphInfo'] = new_paragraphs
        new_books.append(book_copy)
    if new_books:
        rel_path = os.path.relpath(src_path, root_dir)
        save_path = os.path.join(converted_root, rel_path)
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        with open(save_path, 'w', encoding='utf-8-sig') as f:
            if isinstance(data, list):
                json.dump(new_books, f, ensure_ascii=False, indent=2)
            else:
                json.dump(new_books[0], f, ensure_ascii=False, indent=2)

for isbn in sorted(isbn_explicit_set):
    meta_dict[isbn] = isbn_info[isbn]
    meta_list.append(isbn_info[isbn])

# --- 3. Sublabel 복사(하위폴더 전체에서 isbn에 맞는 파일 찾기) ---
def find_sublabel_file(sublabel_dir, isbn):
    for dirpath, _, filenames in os.walk(sublabel_dir):
        for filename in filenames:
            if filename.endswith(f"{isbn}.json"):
                return os.path.join(dirpath, filename)
    return None

copy_ok, copy_fail = 0, 0
for isbn in isbn_explicit_set:
    src_full = find_sublabel_file(sublabel_dir, isbn)
    dst_full = os.path.join(converted_sublabel, f"{isbn}.json")
    if src_full and os.path.exists(src_full):
        shutil.copy2(src_full, dst_full)
        copy_ok += 1
    else:
        print(f"[Sublabel 없음] {isbn}")
        copy_fail += 1
print(f"Sublabel 복사: {copy_ok}개 성공, {copy_fail}개 실패")

# --- 4. 결과 저장 ---
meta_simple_path = os.path.join(json_dir, 'book_titles_by_isbn.json')
with open(meta_simple_path, 'w', encoding='utf-8-sig') as f:
    json.dump([{"isbn": m["isbn"], "title": m["title"]} for m in meta_list], f, ensure_ascii=False, indent=2)

meta_all_path = os.path.join(json_dir, 'book_meta_all.json')
with open(meta_all_path, 'w', encoding='utf-8-sig') as f:
    json.dump(meta_list, f, ensure_ascii=False, indent=2)

meta_books_dir = os.path.join(json_dir, 'books_by_isbn')
os.makedirs(meta_books_dir, exist_ok=True)
for isbn, meta in meta_dict.items():
    meta_path = os.path.join(meta_books_dir, f'{isbn}.json')
    with open(meta_path, 'w', encoding='utf-8-sig') as f:
        json.dump(meta, f, ensure_ascii=False, indent=2)

removed_path = os.path.join(json_dir, 'removed_books.csv')
pd.DataFrame([isbn_info[i] for i in sorted(isbn_removed_set)]).to_csv(removed_path, index=False, encoding='utf-8-sig')

print(f"[최종] 전체 고유 isbn: {len(isbn_all_set)}")
print(f"[최종] 명시적 질문 있는 책: {len(isbn_explicit_set)}")
print(f"[최종] 명시적 질문 없는 책: {len(isbn_removed_set)}")
print(f"모든 전처리/저장 완료!")
# Out:
# 전체 isbn 고유권수: 286
# 명시적 질문 1개 이상 있는 책 권수: 284
# 명시적 질문 0개인 책 권수: 2
# [Sublabel 없음] 9791159420160
# [Sublabel 없음] 9791159420054
# [Sublabel 없음] 9791128208904
# Sublabel 복사: 281개 성공, 3개 실패
# [최종] 전체 고유 isbn: 286
# [최종] 명시적 질문 있는 책: 284
# [최종] 명시적 질문 없는 책: 2
# 모든 전처리/저장 완료!

# %%
# 전체 JSON 파일 개수 세기
json_files = []

for root, dirs, files in os.walk("./converted/Sublabel"):
    for file in files:
        if file.endswith(".json"):
            json_files.append(os.path.join(root, file))

print(f"📂 전체 JSON 파일 수: {len(json_files)}")
# Out:
# 📂 전체 JSON 파일 수: 1721

# %% [markdown]
# ### Unpacking

# %% [markdown]
# import os
# import shutil
#
# base_dir = './converted/sublabel'
#
# # 이동된 파일 수를 세기 위한 변수
# moved_files_count = 0
#
# # 01.원천데이터 폴더가 존재하는지 확인
# if not os.path.isdir(base_dir):
#     print(f"오류: 지정된 경로 '{base_dir}'가 존재하지 않거나 폴더가 아닙니다.")
# else:
#     print(f"'{base_dir}' 폴더에서 .json 파일 이동을 시작합니다.")
#
#     for root, dirs, files in os.walk(base_dir, topdown=False):
#         if root == base_dir:
#             continue
#         for file_name in files:
#             if file_name.endswith('.json'):
#                 source_path = os.path.join(root, file_name)
#                 destination_path = os.path.join(base_dir, file_name)
#
#                 # 파일명 충돌 방지: 이미 대상 폴더에 동일한 파일명이 존재할 경우 처리
#                 if os.path.exists(destination_path):
#                     # 충돌 해결 전략: (3) 이름 변경
#                     base, ext = os.path.splitext(file_name)
#                     counter = 1
#                     new_file_name = f"{base}_{counter}{ext}"
#                     while os.path.exists(os.path.join(base_dir, new_file_name)):
#                         counter += 1
#                         new_file_name = f"{base}_{counter}{ext}"
#
#                     destination_path = os.path.join(base_dir, new_file_name)
#                     print(f"파일명 충돌: '{file_name}' -> '{new_file_name}'으로 변경하여 이동합니다.")
#
#                 try:
#                     shutil.move(source_path, destination_path)
#                     print(f"'{source_path}' -> '{destination_path}' (이동 완료)")
#                     moved_files_count += 1
#                 except Exception as e:
#                     print(f"'{source_path}' 이동 중 오류 발생: {e}")
#
#         # 파일 이동 후, 현재 하위 디렉토리(root)가 비어있으면 삭제
#         try:
#             if not os.listdir(root):
#                 os.rmdir(root)
#                 print(f"빈 디렉토리 삭제: '{root}'")
#         except OSError as e:
#             print(f"빈 디렉토리 '{root}' 삭제 중 오류 발생 (아마도 비어있지 않거나 권한 문제): {e}")
#
#     print(f"\n모든 .json 파일 이동이 완료되었습니다. 총 {moved_files_count}개의 파일이 이동되었습니다.")

# %% [markdown]
# ### Lookup dataset

# %%
import os

def check_sublabel_completeness(converted_base_dir):
    """
    training, validation 경로의 .json 파일명들을 sublabel 경로의 .json 파일명과 비교하여
    누락된 목록과 개수를 출력합니다.

    Args:
        converted_base_dir (str): 'converted' 폴더의 절대 또는 상대 경로.
                                  예: './converted' 또는 'C:/Users/user/project/converted'
    """
    training_dir = os.path.join(converted_base_dir, 'training')
    validation_dir = os.path.join(converted_base_dir, 'validation')
    sublabel_dir = os.path.join(converted_base_dir, 'sublabel')

    # 1. training 및 validation 경로의 모든 JSON 파일명 수집 (중복 제거)
    all_source_filenames = set()

    # training 디렉토리 탐색
    print(f"'{training_dir}' 에서 .json 파일 목록을 수집 중...")
    if not os.path.isdir(training_dir):
        print(f"경고: '{training_dir}' 경로가 존재하지 않습니다.")
    else:
        for root, _, files in os.walk(training_dir):
            for file_name in files:
                if file_name.endswith('.json'):
                    all_source_filenames.add(file_name)
        print(f"'{training_dir}' 에서 총 {len(all_source_filenames)}개의 고유 .json 파일명 수집 완료.")


    # validation 디렉토리 탐색 (기존 all_source_filenames에 추가)
    print(f"'{validation_dir}' 에서 .json 파일 목록을 수집 중...")
    if not os.path.isdir(validation_dir):
        print(f"경고: '{validation_dir}' 경로가 존재하지 않습니다.")
    else:
        current_source_count = len(all_source_filenames)
        for root, _, files in os.walk(validation_dir):
            for file_name in files:
                if file_name.endswith('.json'):
                    all_source_filenames.add(file_name)
        print(f"'{validation_dir}' 에서 추가로 {len(all_source_filenames) - current_source_count}개의 고유 .json 파일명 수집 완료.")

    total_source_count = len(all_source_filenames)
    print(f"\n총 (training + validation) 고유 .json 파일 개수: {total_source_count}개")

    # 2. sublabel 경로의 모든 JSON 파일명 수집
    all_sublabel_filenames = set()
    print(f"\n'{sublabel_dir}' 에서 .json 파일 목록을 수집 중...")
    if not os.path.isdir(sublabel_dir):
        print(f"오류: '{sublabel_dir}' 경로가 존재하지 않습니다. 이 폴더가 없으면 비교할 수 없습니다.")
        return # sublabel 폴더가 없으면 함수 종료

    for root, _, files in os.walk(sublabel_dir):
        for file_name in files:
            if file_name.endswith('.json'):
                all_sublabel_filenames.add(file_name)

    total_sublabel_count = len(all_sublabel_filenames)
    print(f"'{sublabel_dir}' 에서 총 {total_sublabel_count}개의 고유 .json 파일명 수집 완료.")

    # 3. 비교 및 결과 출력
    # training/validation에는 있지만 sublabel에는 없는 파일
    missing_in_sublabel = all_source_filenames - all_sublabel_filenames
    
    print("\n--- 비교 결과 ---")
    print(f"Training/Validation 총 고유 파일 개수: {total_source_count}개")
    print(f"Sublabel 총 고유 파일 개수: {total_sublabel_count}개")

    if not missing_in_sublabel:
        print("\n✅ 모든 Training/Validation 파일이 Sublabel에 존재합니다!")
    else:
        print(f"\n❌ Sublabel에 없는 Training/Validation 파일 개수: {len(missing_in_sublabel)}개")
        print("\nSublabel에 없는 파일 목록:")
        # 정렬하여 출력하면 보기 좋습니다.
        for filename in sorted(list(missing_in_sublabel)):
            print(f"- {filename}")

# --- 함수 호출 ---
# 여기에 'converted' 폴더의 실제 경로를 입력하세요.
# 예: converted_base_directory = 'C:/Users/사용자명/내프로젝트/converted'
# 또는 현재 주피터 노트북 파일이 'converted' 폴더와 같은 레벨에 있다면:
converted_base_directory = './converted' 

check_sublabel_completeness(converted_base_directory)
# Out:
# './converted\training' 에서 .json 파일 목록을 수집 중...
# './converted\training' 에서 총 1443개의 고유 .json 파일명 수집 완료.
# './converted\validation' 에서 .json 파일 목록을 수집 중...
# './converted\validation' 에서 추가로 284개의 고유 .json 파일명 수집 완료.
#
# 총 (training + validation) 고유 .json 파일 개수: 1727개
#
# './converted\sublabel' 에서 .json 파일 목록을 수집 중...
# './converted\sublabel' 에서 총 2342개의 고유 .json 파일명 수집 완료.
#
# --- 비교 결과 ---
# Training/Validation 총 고유 파일 개수: 1727개
# Sublabel 총 고유 파일 개수: 2342개
#
# ❌ Sublabel에 없는 Training/Validation 파일 개수: 4개
#
# Sublabel에 없는 파일 목록:
# - 03_02T_02S_9788961914314.json
# - 03_03T_03S_9791128208904.json
# - 03_03T_03S_9791159420054_.json
# - 03_03T_03S_9791159420160_.json

# %% [markdown]
# ### Check token size

# %%
import json, sys, re
from pathlib import Path
from tqdm import tqdm

BASE = Path("./converted/formatted")
SPLITS = ["train", "val"]

def load_json(fp):
    with open(fp, "r", encoding="utf-8") as f:
        return json.load(f)

def fail(msg, errors, fp):
    errors.append(f"{fp} :: {msg}")

def validate_file(fp):
    errors=[]
    try:
        js = load_json(fp)
    except Exception as e:
        return [f"{fp} :: JSON load error – {e}"]

    if "data"   not in js: fail("'data' key missing", errors, fp)
    if "version" not in js: fail("'version' key missing", errors, fp)

    for d_i, data in enumerate(js.get("data", [])):
        if "title" not in data: fail(f"[data[{d_i}]] 'title' missing", errors, fp)
        for p_i, para in enumerate(data.get("paragraphs", [])):
            context = para.get("context")
            if context is None: fail(f"[{d_i}][{p_i}] context missing", errors, fp)
            for q_i, qa in enumerate(para.get("qas", [])):
                qid = qa.get("id", "<no-id>")
                if "question" not in qa:  fail(f"{qid} question missing", errors, fp)
                if "is_impossible" not in qa:
                    fail(f"{qid} is_impossible missing", errors, fp)
                    continue
                imps = qa["is_impossible"]

                ans_list = qa.get("answers", [])
                if imps and ans_list:
                    fail(f"{qid} marked impossible but answers provided", errors, fp)
                if not imps and not ans_list:
                    fail(f"{qid} possible but answers empty", errors, fp)

                # answer-context 정합성
                for a_i, ans in enumerate(ans_list):
                    text = ans.get("text")
                    pos  = ans.get("answer_start")
                    if text is None or pos is None:
                        fail(f"{qid} answer[{a_i}] missing field", errors, fp)
                        continue
                    if context is not None and context[pos:pos+len(text)] != text:
                        snippet = context[pos:pos+len(text)]
                        fail(f"{qid} answer mismatch (ctx:'{snippet}' vs ans:'{text}')", errors, fp)
    return errors

def validate_split(split):
    print(f"\n🔍 VALIDATE {split.upper()}")
    split_dir = BASE / split
    issues=[]
    for fp in tqdm(list(split_dir.glob("*.json"))):
        issues.extend(validate_file(fp))
    if issues:
        print(f"❌ {len(issues)} issue(s) found in {split} files")
        for msg in issues[:20]:   # 처음 20개만 미리보기
            print("   •", msg)
    else:
        print("✅ all {split} files are valid")

for s in SPLITS:
    validate_split(s)

print("\n🟢 검증 완료")

# %% [markdown]
# ### formatting

# %%
# ╔═══════════════╗
# ║  🟢  Cell 1   ║  말뭉치 생성 스크립트
# ╚═══════════════╝
import json, re, hashlib, sys
from pathlib import Path
from typing import Union, Dict, List
from tqdm.auto import tqdm

# ───────── 경로 설정 ─────────
ROOT      = Path('./converted')
TRAIN_LB  = ROOT/'training'  /'02.라벨링데이터'
VAL_LB    = ROOT/'validation'/'02.라벨링데이터'
SUB_DIR   = ROOT/'sublabel'
OUT_DIR   = ROOT/'formatted';  OUT_DIR.mkdir(exist_ok=True)

# ───────── ISBN 추출 ─────────
ISBN_RE = re.compile(r'(\d{9,13}X?)_?(?=\.json$)')   # 뒤쪽 '_' 허용
def isbn_from_name(src: Union[str, Path]) -> str:
    name = src.name if hasattr(src, 'name') else str(src)
    m = ISBN_RE.search(name)
    if not m:
        raise ValueError(f'ISBN not found: {name}')
    return m.group(1)

# ───────── 로딩 함수 ─────────
def load_dir(p: Path) -> Dict[str, dict]:
    return {isbn_from_name(f): json.loads(f.read_text('utf-8-sig'))
            for f in p.glob('*.json')}

def load_sublabels(p: Path) -> Dict[str, str]:
    tmp: Dict[str, List[str]] = {}
    for f in p.glob('*.json'):
        isbn = isbn_from_name(f)
        txt  = json.loads(f.read_text('utf-8-sig'))['text']
        tmp.setdefault(isbn, []).append(txt)
    return {k: '\n\n'.join(v) for k, v in tmp.items()}

print("📄  loading …")
train_lbl = load_dir(TRAIN_LB)
val_lbl   = load_dir(VAL_LB)
sub_txt   = load_sublabels(SUB_DIR)
print(f"  train label {len(train_lbl)} | val label {len(val_lbl)} | sub {len(sub_txt)}")

# ───────── KorQuAD entry ─────────
def entry(isbn: str, lbl: dict, context: str) -> dict|None:
    qas = []
    missed_qas = []  # 🔸 missed QA 저장용
    for qa in lbl_doc["paragraphInfo"][0]["queAnsPairInfo"]:
        qid = f'{isbn}-{hashlib.md5(qa["question"].encode()).hexdigest()[:8]}'
        ans = qa["ansM1"]
        start = context.find(ans)
        if start == -1:
            missed_qas.append((qa["question"], ans))
            continue
        qas.append({
            "id": qid,
            "question": qa["question"],
            "answers": [{"text": ans, "answer_start": start}]
        })
    return {
        "title": lbl_doc["title"],
        "paragraphs": [{
            "context": context,
            "qas": qas
        }]
    }, missed_qas

def make_split(lbl_pool: Dict[str, dict], split: str):
    data, skip = [], []
    for isbn, doc in tqdm(lbl_pool.items(), desc=f"{split.upper()}"):
        ctx = sub_txt.get(isbn)
        if not ctx: skip.append(isbn); continue
        ent = entry(isbn, doc, ctx)
        if ent: data.append(ent)
    out = OUT_DIR/f"{split}.json"
    out.write_text(json.dumps({"version":"v1.0","data":data},
                              ensure_ascii=False, indent=2), encoding='utf-8')
    print(f"✅ {out.name} — books:{len(data)}  no-sub:{len(skip)}")

make_split(train_lbl,'train')
make_split(val_lbl,  'val')
# Out:
# 📄  loading …
#   train label 1443 | val label 284 | sub 1725
# TRAIN:   0%|          | 0/1443 [00:00<?, ?it/s]
# ⚠️  miss [9791128212765] 무서운 뱀인줄 알고 어떻게 하자고 했나요?…
# ⚠️  miss [9791128216725] 여우가 우주선을 타고 있는 걸 본 친구들은 뭐…
# ⚠️  miss [9791128216893] 동물은 꿀꿀 하고 무엇을 내나요?…
# ⚠️  miss [9791128216893] ㅂ으로 시작되는 이름을 가진 과일 중 길쭉한 …
# ⚠️  miss [9791128216893] 첫 글자를 보고 우리는 무엇을 해야 하나요?…
# ⚠️  miss [9791128216961] 나비는 무엇을 하나요?…
# ⚠️  miss [9791128216961] 모두모두 무엇을 했나요?…
# ⚠️  miss [9791128216985] 도토리 달을 먹은 다람쥐는 어떻게 하나요?…
# ⚠️  miss [9791159424496] 막내 공주가 연못가에서 공을 가지고 놀다가 어…
# ⚠️  miss [9791159424496] 막내 공주의 눈물이 개구리에게 떨어지자 무슨 …
# ⚠️  miss [9791159424502] 아이들은 정원에서 어떻게 놀았나요?…
# ⚠️  miss [9791159424564] 꼬투리를 꺾었을 때 완두콩 오형제는 바깥세상으…
# ⚠️  miss [9791159424601] 새 왕비는 요술 거울에 어떤 질문을 했나요?…
# ⚠️  miss [9791159424618] 엉터리 재단사가 가지고 온 옷감은 어떤 특징을…
# ⚠️  miss [9791159424632] 빨간 모자는 어디를 걸어갔나요?…
# ⚠️  miss [9791159424649] 마리아가 발견한 것은 무엇인가요?…
# ⚠️  miss [9791159424649] 욕심이 생긴 새엄마는 안나에게 어떤 말을 했나…
# ⚠️  miss [9791159424755] 잭과 엄마는 어디에서 사나요?…
# ⚠️  miss [9791159425004] 선비가 죽인 것은 누구인가요?…
# ⚠️  miss [9791165430276] 자박자박은 돼지가 무슨 행동을 할때 나오는 소…
# ⚠️  miss [9791165432300] 무엇을 품어 보려고 하는 걸까요?…
# ⚠️  miss [9791165432430] 넓은 어항에서 살랑살랑 무엇을 할까요?…
# ⚠️  miss [9791165435011] 아기 코끼리가 일어난 뒤에 어떻게 말했나요?…
# ⚠️  miss [9791165435035] 누가 다시 깡충깡충 뛸 수 있다고 했나요?…
# ⚠️  miss [9791165435035] 신발 때문에 뛰지 못한 토끼가 어떻게 되었나요…
# ⚠️  miss [9791165435073] 기린은 무엇을 하고 있었나요?…
# ⚠️  miss [9791165435073] 생쥐를 도와준 것은 누구인가요?…
# ⚠️  miss [9791165435912] 차를 마시고 있는 동물은 누구인가요?…
# ⚠️  miss [9791165435912] 얼룩소는 무엇을 하고 있나요? …
# ⚠️  miss [9791165435943] 무엇을 보고 어떤 소리가 날지 궁금해했나요? …
# ⚠️  miss [9791165435974] 돌고래는 바다에서 휘익휘익 무엇을 하고 있나요…
# ⚠️  miss [9791165436063] 느리지만 달리는 걸 좋아하는 건 누구인가요?…
# ⚠️  miss [9791165436063] 아기 곰은 스스로를 어떻게 생각하나요?…
# ⚠️  miss [9791165953973] 무지개색을 보고 어떤 느낌이 들었나요?…
# ⚠️  miss [9788927201311] 민들레는 어떻게 아들을 찾아 나섰나요?…
# ⚠️  miss [9788927201458] 섬에 혼자 남은 딸아이가 걱정된 아버지는 어떻…
# ⚠️  miss [9788927201465] 내리는 비를 향해 여기저기 손을 내미는 것은 …
# ⚠️  miss [9788927201465] 비가 와서 놀이터에서 놀지 못한 나의 기분은 …
# ⚠️  miss [9788927201465] 비가 오면 나는 왜 싫은가요?…
# ⚠️  miss [9788927201465]  비에 옷이 젖는 건 싫지만 나는 엄마를 따라…
# ⚠️  miss [9788954337618] 꿀벌들이 선물로 받은 것은 무엇일까요?…
# ⚠️  miss [9788954337632] 베짱이에게 음식을 주고 싶어 하는 개미는 베짱…
# ⚠️  miss [9788954337649] 거북과 달리기 시합을 하게 된 토끼는 어떤 감…
# ⚠️  miss [9788954337649] 앉아있던 토끼는 어떤 행동을 했나요?…
# ⚠️  miss [9788954337663] 모기는 친구들에게 뭐라고 얘기했나요?…
# ⚠️  miss [9788954337748] 타미는 머리를 어디에 부딪혔나요? …
# ⚠️  miss [9788954337755] 벌집에 들어갈 수 없는 건 누구와 누구인가요?…
# ⚠️  miss [9788954337823] 원숭이랑 곰이랑 여우가 사이좋게 걸어오자 나는…
# ⚠️  miss [9788954337830] 들소 세 친구의 모습은 어떤가요?…
# ⚠️  miss [9788954337854] 깊고 깊은 숲 속에서 족제비 아가씨가 무엇을 …
# ⚠️  miss [9788954337861] 뚱보 아주머니는 꿀꿀이죽외에 암탉에게 어떤 먹…
# ⚠️  miss [9788954337878] 집을 짓기 시작한 주인공이 나무와 흙을 가지고…
# ⚠️  miss [9788992111508] 쿵쿵쿵 코끼리는 목욕을 하면 어떤 느낌이 든다…
# ⚠️  miss [9788997300655] 흉내쟁이는 어떤 동물들을 흉내 냈나요?…
# ⚠️  miss [9788997300716] 생쥐와 코끼리는 선물을 보고 어떤 말을 했나요…
# ⚠️  miss [9788997300792] 사과 아줌마는 무엇을 먹으려고 식탁에 앉았나요…
# ⚠️  miss [9788997300792] 사과파이의 맛은 어땠나요?…
# ⚠️  miss [9788997300792] 오븐을 열자 어떻게 되었나요?…
# ⚠️  miss [9788997300846] 다섯 번째 아기 돼지가 나타나 뭐라고 이야기 …
# ⚠️  miss [9788997300860] 달님은 촘촘히 엮은 그물코에 걸렸을까요?…
# ⚠️  miss [9788997300884] 곰동이가 삼각대를 갖고 나오며 뭐라고 말했나요…
# ⚠️  miss [9791128210358] 그레텔은 오빠에게 뭐라고 했나요?…
# ⚠️  miss [9791128210396] 쥐를 부른 이유는 무엇인가요?…
# ⚠️  miss [9791128210464] 어마어마한 무엇을 달라고 할까 생각했나요?…
# ⚠️  miss [9791128210464] 뭐라고 말하며 투덜거렸나요?…
# ⚠️  miss [9791165432584] 빙그르르 날고 있는 점점이를 보고 유미는 무슨…
# ⚠️  miss [9791165432584] 점점이가 초대한 파티는 언제 열렸나요?…
# ⚠️  miss [9791165432607] 무엇으로 변하지 않았나요?…
# ⚠️  miss [9791165432614] 사람처럼 옷을 입은 고양이들이 뭐라고 물어봤나…
# ⚠️  miss [9791165432614] 공터에 도착한 개구쟁이 특공대는 어떤 행동을 …
# ⚠️  miss [9791165432638] 유미와 은찬이가 물웅덩이의 진흙을 튀기며 준이…
# ⚠️  miss [9791165432638] 은찬 왕자랑 유미 공주 그리고 준 박사는 뛰어…
# ⚠️  miss [9791165433987] 친구들이 발견한 스테고사우루스는 무엇을 하고 …
# ⚠️  miss [9791165434045] 웃으면서 서있었던 사람은 누구인가요?…
# ⚠️  miss [9791165434090] 오늘은 무슨 날이었나요?…
# ⚠️  miss [9791165950057] 꼬마 돼지는 무슨 옷을 입은 모습을 상상 했나…
# ⚠️  miss [9791165950064] 쫑아가 얼음을 어떻게 했을까요?…
# ⚠️  miss [9791165950095] 빈이의 이를 잘 닦은 노란 칫솔은 내일은 무엇…
# ⚠️  miss [9791165950125] 누가 카레를 먹었나요?…
# ⚠️  miss [9791165950125] 깡총사우루스가 무엇을 하자고 했나요?…
# ⚠️  miss [9791165950125] 누구한테 한 그릇 더 달라고 할 건가요?…
# ⚠️  miss [9791165950132] 재미있는 놀이가 많다고 한 곳은 어디 인가요?…
# ⚠️  miss [9791165950149] 화가 난 물건들이 소리치자 가족들이 어떤 감정…
# ⚠️  miss [9791165950200] 다람쥐 마을은 어디에 있었을까요?…
# ⚠️  miss [9791165950255] 깍두기를 담그자는 두더지의 말에 오소리는 뭐라…
# ⚠️  miss [9791165950293] 1층에 들어간 음식은 무엇인가요?…
# ⚠️  miss [9791165950309] 어떤 초코케이크가 들어 있었나요?…
# ⚠️  miss [9791165950309] 무엇을 보고 입이 쩍 벌어졌을까요?…
# ⚠️  miss [9791165950347] 꼬마 강아지의 앞머리는 어떻게 됐나요?…
# ⚠️  miss [9791165950347] 꼬마 강아지가 앞머리가 자꾸 흘러내린다고 해서…
# ⚠️  miss [9791165952525] 쥐와 고양이가 친구들을 도와주었는데 빨간 사과…
# ⚠️  miss [8975253589] 누가 엄하게 말했나요?…
# ⚠️  miss [8975253589] 멋쟁이새와 곤줄박이가 어디에 나타났나요?…
# ⚠️  miss [8975253589] 곧 여우의 먹이가 되고 말 동물은 누구인가요?…
# ⚠️  miss [8975253589] 아미크가 노는 곳은 어디인가요?…
# ⚠️  miss [8975253589] 크리키는 어디에 들어가 놀았나요?…
# ⚠️  miss [8975253589] 누가 투덜거렸나요?…
# ⚠️  miss [8975253589] 말괄량이 오리는 누구인가요?…
# ⚠️  miss [8975253589] 스푼이어는 누가 힘이 약하다고 했나요?…
# ⚠️  miss [8975253589] 아버지는 비버를 찾으러 어디를 다녔나요?…
# ⚠️  miss [8975253589] 인디언 오누이는 무엇을 했나요?…
# ⚠️  miss [8975253589] 돌들이 널려있는 곳은 어디인가요?…
# ⚠️  miss [8975253589] 크리키는 어디로 달아나려 했나요?…
# ⚠️  miss [8975253589] 비가 오는 동안 살쾡이는 어디에 숨어 있었나요…
# ⚠️  miss [8975253589] 바구니에 무엇이 가득 찼나요?…
# ⚠️  miss [8975253589] 여우는 누가 아직 목적지에 도착하지 못했다고 …
# ⚠️  miss [8975253589] 모두 어떤 상태인가요?…
# ⚠️  miss [8975253589] 모두 어떤 행동을 하지 않았나요?…
# ⚠️  miss [8975253589] 오빠가 주워 온 자작나무 껍질로 오페키는 무엇…
# ⚠️  miss [8975253589] 자작나무 껍질은 어느 지역에 사는 인디언들에게…
# ⚠️  miss [8975253589] 늙은 오리는 다른 오리들에게 무엇을 하라고 외…
# ⚠️  miss [8975253589] 비버 집에 누가 살고 있었나요?…
# ⚠️  miss [8975253589] 아미크와 신부는 왜 오페키와 놀지 않았나요?…
# ⚠️  miss [8975253589] 두 마리의 용감한 토끼들은 누구를 가운데 두고…
# ⚠️  miss [8975253589] 누가 맨 뒤에 따라갔나요?…
# ⚠️  miss [8975253589] 오늘 까마귀와 친구들은 무엇을 했나요?…
# ⚠️  miss [8975253589] 누가 아기 오리 다섯 마리와 함께 왔나요?…
# ⚠️  miss [8975253589] 아기 비버는 무엇을 하고 있었나요?…
# ⚠️  miss [8975253589] 여우가 어떻게 행동했나요?…
# ⚠️  miss [8975253589] 여우는 어디에 앞발을 넣었나요?…
# ⚠️  miss [8975253589] 여우는 토끼 사이에 누가 숨어 있다고 생각했나…
# ⚠️  miss [8975253589] 도둑은 포기하지 않고 어떻게 행동했나요?…
# ⚠️  miss [8975253589] 오페키는 남동생이 태어났다는 말을 듣고 어떻게…
# ⚠️  miss [8975253589] 크리키는 어디로 헤엄쳐 갔나요?…
# ⚠️  miss [8975253589] 오리의 집에는 무엇이 들어 있었나요?…
# ⚠️  miss [8975253589] 여우는 누구에게 내일 또 만나자고 말했나요?…
# ⚠️  miss [8975253589] 여우가 와도 걱정 없는 곳은 어디인가요?…
# ⚠️  miss [8975253589] 얼음과 추위에 관해 물어볼 수 없었던 것은 누…
# ⚠️  miss [8975253589] 인사도 하지 못하고 무리에 섞여서 날아오른 것…
# ⚠️  miss [8975253589] 엄마 비버는 누구를 걱정했나요?…
# ⚠️  miss [8975253589] 그림자가 언제 길게 늘어났나요?…
# ⚠️  miss [8975253589] 인디언 가족 외엔 아무도 살지 않았던 장소는 …
# ⚠️  miss [8975253589] 여우는 아직도 누구를 찾는 것을 포기하지 않았…
# ⚠️  miss [8975253589] 누가 물살에 휩쓸렸나요?…
# ⚠️  miss [8975253589] 막내 아기비버는 누가 부르는 소리를 들었나요?…
# ⚠️  miss [8975253589] 무엇이 다 녹았나요?…
# ⚠️  miss [8975253589] 누가 외쳤지만, 소용이 없었나요?…
# ⚠️  miss [8975253589] 크리키는 재빨리 어디로 들어갔나요?…
# ⚠️  miss [8975253589] 누가 신기한 것을 좋아했나요?…
# ⚠️  miss [8975253600] 칼레는 어디에 앉았나요?…
# ⚠️  miss [8975253600] 검은 사람은 뭐라고 말했나요?…
# ⚠️  miss [8975253600] 칼레는 여기가 싫어져서 어떻게 했나요?…
# ⚠️  miss [8975253600] 사나이는 어딜 같이 가자고 했나요?…
# ⚠️  miss [8975253600] 칼레는 왜 아이스크림 기계 위에서 자기로 했었…
# ⚠️  miss [8975253600] 선생님에게 물어보려고 칼레는 어디를 지나갔나요…
# ⚠️  miss [8975253600] 눈사람은 모두 같이 있는 것만으로 기뻐해야 하…
# ⚠️  miss [8975253600] 사나이는 당황하지 말라며 칼레에게 어떻게 행동…
# ⚠️  miss [8975253600] 우리는 누구인가요?…
# ⚠️  miss [8975253600] 서커스와 달라 어디인가요?…
# ⚠️  miss [8975253600] 아이들은 소리를 합쳐 무엇을 외쳤나요?…
# ⚠️  miss [8975253600] 서커스의 이름은 무엇인가요?…
# ⚠️  miss [8975253600] 클레는 공연 표를 사기 위해 어떻게 행동하였나…
# ⚠️  miss [8975253600] 선생님은 책을 뽑아 어떻게 하였나요?…
# ⚠️  miss [8975253600] 가게 주인은 어떻게 되었나요?…
# ⚠️  miss [8975253600] 칼레는 어디에서의 일을 무슨 생각을 했나요?…
# ⚠️  miss [8975253600] 칼레는 무엇을 안고 있어서 창문을 두드릴 수 …
# ⚠️  miss [8975253600] 칼레는 이 추위가 누구 탓이라고 생각했나요?…
# ⚠️  miss [8975253600] 추위가 자기 탓이라고 생각한 칼레는 기분이 어…
# ⚠️  miss [8975253600] 여자 눈사람은 춤을 추려 하지 않고 어떻게 행…
# ⚠️  miss [8975253600] 빵 가게 주인은 무엇을 쓰고 읽었나요?…
# ⚠️  miss [8975253600] 소리를 듣고 사나이는 옆을 보며 어떻게 행동하…
# ⚠️  miss [8975253600] 지금은 어떤 시간이라고 하였나요?…
# ⚠️  miss [8975253600] 쓸모없다고 한 것은 무엇일까요?…
# ⚠️  miss [8975253600] 클레는 어떤 표정을 지었나요?…
# ⚠️  miss [8975253600] 어디에서 손님이 몇 사람 나갔나요?…
# ⚠️  miss [8975253600] 칼레는 곧 가라앉게 된다며 대통령에게 어떻게 …
# ⚠️  miss [8975253600] 얀이 칼레에 아내를 찾으라고 말하고 어떻게 행…
# ⚠️  miss [8975253600] 칼레는 여우 라이네케 셀에게 인사하며 어떤 행…
# ⚠️  miss [8975253651] 막스는 선생님에게 뭐라고 부탁했을까요?…
# ⚠️  miss [8975253651] 선생님은 어떻게 하면서 곰곰 생각해 보았나요?…
# ⚠️  miss [8975253651] 도펠트 교장 선생님은 파이어리히 선생에게 무엇…
# ⚠️  miss [8975253651] 아이들이 무엇을 하고 있었을까요?…
# ⚠️  miss [8975253651] 테디는 무엇을 불어 시합을 중지시켰나요?…
# ⚠️  miss [8975253651] 마술사는 바샤와 말을 보고 어떤 감정을 느꼈을…
# ⚠️  miss [8975253651] 자기가 다른 사람이 된 것을 알아차린 선생님은…
# ⚠️  miss [8975253651] 선생님은 어떻게 살아왔나요?…
# ⚠️  miss [8975253651] 테디는 파이어리히 선생님에게 무엇을 했을까요?…
# ⚠️  miss [8975253651] 테디는 왜 일부러 화가 난 듯이 말했을까요?…
# ⚠️  miss [8975253651] 푼첼 아저씨는 무엇이 꺼림칙한 일이었나요?…
# ⚠️  miss [8975253651] 테디는 자기도 모르게 어떻게 하고 있었나요?…
# ⚠️  miss [8975253651] 테디는 왜 자기도 모르는 사이에 선생님 표정을…
# ⚠️  miss [8975253651] 막스와 미체는 또 언제 선생님 수염을 깎아 드…
# ⚠️  miss [9788961911399] 미요는 유치원 노래자랑에서 무엇을 해야 하나요…
# ⚠️  miss [9788961911689] 해마다 가을이면 어디에서 축구 대회가 열리나요…
# ⚠️  miss [9788959042203] 벌레잡이 식물은 잡은 벌레들을 소화하기 위해 …
# ⚠️  miss [9788959042203] 긴 털을 활짝 펴는 이유는 무엇인가요?…
# ⚠️  miss [9788959042203] 끈끈이주걱은 파리를 어떤 방법으로 먹을 수 있…
# ⚠️  miss [9788959042203] 네펜데스라고 부르는 외국 식물은 어떤 특징이 …
# ⚠️  miss [9788959042203] 털을 두 번 건드리면 어떻게 되나요?…
# ⚠️  miss [9788959042203] 식충식물들은 어디에서 자라고 있나요?…
# ⚠️  miss [9788959042210] 광합성을 이용해서 무엇을 얻는다고 하였나요?…
# ⚠️  miss [9788959042210] 여러가지 초록색이란 말에 아빠는 뭐라고 했나요…
# ⚠️  miss [9788959042210] 토끼 삼 형제는 기분이 어땠나요?…
# ⚠️  miss [9788959042210] 엽록소가 햇빛의 색 중 빨간빛과 파란빛을 더 …
# ⚠️  miss [9788959042258] 누가 머리에 달려 있는 빨판을 이용해 대왕쥐가…
# ⚠️  miss [9788959042319] 세상에서 가장 신기한 마술을 보고 싶은 사람은…
# ⚠️  miss [9788959042357] 해가 진 후 서쪽 하늘에서, 해뜨기 전 동쪽 …
# ⚠️  miss [9788959042357] 높이 2킬로미터에 길이가 수백 킬로미터에 이르…
# ⚠️  miss [9788959042357] 선장이 내게 항해 일지와 항해 지도를 준 건 …
# ⚠️  miss [9788959042371] 아무도 자신의 배꼽에 신경쓰지 않는다는 생각에…
# ⚠️  miss [9788959042371] '달이 밤에도 빛을 내니까 길을 잃지 않겠네'…
# ⚠️  miss [9788959042463] 세모, 네모난 물체는 굴리면 어떻게 될까요?…
# ⚠️  miss [9788959042487] 세계 최초로 흑백텔레비전 방송을 언제 어느 곳…
# ⚠️  miss [9788959042494] 커다란 배들이 아래쪽에 빨간색을 칠하는 이유는…
# ⚠️  miss [9788959042494] 아주 먼 옛날 사람들은 어떻게 생활했나요?…
# ⚠️  miss [9788959042494] 왜 어떤 물체는 물 위에 뜨고 어떤 물체는 물…
# ⚠️  miss [9788959042494] 잠수함은 어떻게 가라앉을까요? …
# ⚠️  miss [9788959042494] 물이 넘치는 걸 보고 무엇을 알 수 있었나요?…
# ⚠️  miss [9788959042524] 낙타의 칭찬에 바람은 무얼 했나요?…
# ⚠️  miss [9788959042531] 딱딱이는 파도를 보자 또 어떤 궁금증이 떠올랐…
# ⚠️  miss [9788959042562] 대기의 4개의 층은 대류권과 성층권 외에 또 …
# ⚠️  miss [9788959042586] 사랑들은 호랑이를 사냥해서 어떻게 했나요?…
# ⚠️  miss [9788960162358] 매미의 애벌레는 어디에서 즙을 빨아 먹나요?…
# ⚠️  miss [9788960163119] 해바라기 잎을 무엇으로 비유했나요?…
# ⚠️  miss [9788993828771] 코알라는 어떤 나무의 잎만 먹나요?…
# ⚠️  miss [9788994730028] 누가 공원에서 산책하고 있습니까?…
# ⚠️  miss [9788994730080] 기남이는 트럭에 어떤 행동을 했나요?…
# ⚠️  miss [9788994730097] 끈을 똑같이 반으로 자르니 어떻게 되었나요?…
# ⚠️  miss [9788994730134] 통통 축구공을 받은 아이들은 어떻게 하였나요?…
# ⚠️  miss [9788994730141] 말미잘에 쏘이지 않고 공을 찾을 수 있었던 이…
# ⚠️  miss [9788994730257] 숲에서 무엇을 찾으라고 했나요?…
# ⚠️  miss [9788994730271] 너구리는 동쪽으로 100미터를 재려면 뭐가 필…
# ⚠️  miss [9788994730301] 누가 울음을 터트렸나요?…
# ⚠️  miss [9788994730400] 기린 아저씨가 무엇을 할 때 돼지가 물에 풍덩…
# ⚠️  miss [9788994730424] 까부랑 도깨비는 왜 미끄러졌나요?…
# ⚠️  miss [9788994730424] 누구와 누구가 깜짝 놀라서 달려왔나요?…
# ⚠️  miss [9788994730462] 무엇이 다섯 개 있나요?…
# ⚠️  miss [9788994730462] 첫 번째로 줄 선 원중이는 몇 번째로 도착한 …
# ⚠️  miss [9788994730479] 파란색 크레파스는 어떤 행동을 하며 말하고 있…
# ⚠️  miss [9788994730530] 왕자가 다섯 번째 문을 활짝 열자, 무엇이 나…
# ⚠️  miss [9788994730592] 거꾸로 생각하기가 매우 중요한 이유는 무엇일까…
# ⚠️  miss [9791128212048] 토끼가 깡충깡충,마법 지팡이를 들고 다가와서 …
# ⚠️  miss [9791128212048] 돼지가 자박자박 기차를 끌고 다가와 뭐라고 말…
# ⚠️  miss [9791128212055] 이제 뭐든지 어떻게 할 수 있을까?…
# ⚠️  miss [9791128212055] 딱딱한 밤을 우적우적 왜 먹을 수 있을까?…
# ⚠️  miss [9791128212062] 요리조리 신기한 전화기를 꾹꾹 어떻게 하나요?…
# ⚠️  miss [9791128212079] 선물을 보고 어떤 말을 제일 먼저 했을까요?…
# ⚠️  miss [9791128212178] 수박을 왜 한번 더 자를까요?…
# ⚠️  miss [9791128212178] 사과는 어떻게 딸까요?…
# ⚠️  miss [9791128212208] 바람이 너무 세게 불면 무엇을 할 수 있을까요…
# ⚠️  miss [9791128212208] 장갑 끼고 무엇을 만들까요?…
# ⚠️  miss [9791128212208] 밖은 너무너무 추우면 어떻게 해야 하나요?…
# ⚠️  miss [9791128212208] 놀고 있는 놀지와 꼼지는 어떤 기분이 들까요?…
# ⚠️  miss [9791128212208] 햇빛이 너무 눈부시면 어떻게 하면 되나요?…
# ⚠️  miss [9791128212239] 데굴데굴 떽떼굴 구르는 것은 무엇이었나요? …
# ⚠️  miss [9791128212239] 결국 자전거는 앞으로 어떻게 할 것이라고 했나…
# ⚠️  miss [9791128212246] 지유는 왜 요리조리 쪼르르 도망갈까요?…
# ⚠️  miss [9791128212291] 물을 아끼려면 양치질 할 때  어떻게 해야 할…
# ⚠️  miss [9791128212291] 땅이 푸르게 하려면 어떻게 해야 할까요?…
# ⚠️  miss [9791128212291] 손수건으로 닦으면 어떤 좋은 점이 있을까요?…
# ⚠️  miss [9791128212321] 아기 돼지가 노랑 레몬을 먹으며 뭐라고 외쳤나…
# ⚠️  miss [9791165951207] 배꼽을 가진 동물들 중 강아지나 돼지 또 어떤…
# ⚠️  miss [9791165951511] 밤에 움직이는 동물은 무엇인가요?…
# ⚠️  miss [979116595152] 부리를 이용해 무엇을 할 수 있나요?…
# ⚠️  miss [979116595152] 부리로 무엇을 하나요?…
# ⚠️  miss [979116595152] 넓적한 부리로 무엇을 먹나요?…
# ⚠️  miss [9791165951528] 진달래 꽃잎 따서 무엇을 만드나요?…
# ⚠️  miss [9791165951528] 들판에 꽃들이 한가득 피고, 나비가 이리저리 …
# ⚠️  miss [9791165953416] 나이프를 쓸 때에는 어떻게 해야 할까요?…
# ⚠️  miss [9791165953416] 스파게티를 먹을 때는 디너 포크로 스파게티 면…
# ⚠️  miss [9791165953423] 소매 길이를 딱 맞게 줄이려면 어떻게 해야 할…
# ⚠️  miss [9791165953560] 주름은 어떤 뜻을 가지고 있나요?…
# ⚠️  miss [9791165953713] 산타할아버지에게 어떤 말로 안심시켜 드리고 있…
# ⚠️  miss [9791165953713] 오리오는 멀리서도 이리저리 조종할 수 있는 자…
# ⚠️  miss [9791186298138] 지구의 배꼽을 찾기 위해 앞으로 어떤 일을 할…
# ⚠️  miss [9788961914185] 빛이 온 세상을 비추면 어떻게 될까요?…
# ⚠️  miss [9788961914215] 식물은 물을 어떻게 하나요?…
# ⚠️  miss [9788966923014] 남극같이 서늘했던 곳은 어디일까요?…
# ⚠️  miss [9788966923632]  토끼 입 안에서 넷 나온 것은 무엇인가요?…
# ⚠️  miss [9788966923670] 물놀이할 때 쓸 것은 무엇인가요?…
# ⚠️  miss [9788966923670] 맛있는 것은 무엇인가요?…
# ⚠️  miss [9791128213960] 내 키가 크는 것처럼 나무도 어떻게 될까요?…
# ⚠️  miss [9791128214127] 교통신호는 무엇인가요?…
# ⚠️  miss [9791157025923] 왠지 기운이 없어 보이는 건 누구일까요?…
# ⚠️  miss [9791157025930] 투덜이가 들어간 서점의 이름은 뭔가요?…
# ⚠️  miss [9791157025930] 카오스 머신이 도착한 곳은 어디인가요?…
# ⚠️  miss [9791157025930] 카오스 머신에는 누가 탔나요?…
# ⚠️  miss [9791157025930] 삼총사는 황 박사님의 말에 어떻게 했나요?…
# ⚠️  miss [9791157026012] 어디에 가면 줄기세포를 구할 수 있다고 했나요…
# ⚠️  miss [9791157026012] 방학을 맞은 삼총사는 어디에 모였나요?…
# ⚠️  miss [9791157026159] 전단지 내용에는 무엇이 쓰여 있었나요?…
# ⚠️  miss [9791157026159] 고양이는 숨어 있기 선수라고 누가 말했을까요?…
# ⚠️  miss [9791157026166] 박사님이 책상 가운데에 둥글납작한 접시를 내려…
# ⚠️  miss [9791157026166] 저녁을 먹는 내내 마리의 마음이 불편했던 이유…
# ⚠️  miss [9791157026173] 황박사님이 지구로 돌아가자고 외치자, 카오스머…
# ⚠️  miss [9791157026234] 달이 어떤 이유로 빛나 보인다고 했나요?…
# ⚠️  miss [9791157026234] 박사님의 설명을 듣고 한 말은 무엇인가요?…
# ⚠️  miss [9791157026258] 크리스마스 트리를 꾸미기 위해 무엇을 했나요?…
# ⚠️  miss [9791157026289] 장난꾸러기 삼총사는 누굴 만나러 북극에 왔나요…
# ⚠️  miss [9791157026432] 삼총사가 잽싸게 간 곳은 어디일까요?…
# ⚠️  miss [9791157026432] 투덜이가 햄버거의 역사에 알려 달라고 하자, …
# ⚠️  miss [9791157026432] 유비와 투덜이에게 생긴 이상한 일은 무엇일까요…
# ⚠️  miss [9791157594597] 돼지 삼 형제는 늑대를 피해 어디에 숨었나요?…
# ⚠️  miss [9791157595235] 기차를 닮은 내 장화는 칙칙폭폭 어디로 돌아가…
# ⚠️  miss [9791165434625] 복어는 무엇을 잡아먹나요?…
# ⚠️  miss [9791165434656] 나는 개구리를 어떻게 했나요?…
# ⚠️  miss [9791165434694] 씨름을 할 때 허리는 무엇으로 잡나요?…
# ⚠️  miss [9791165435110] 아이들이 서로서로 무엇을 하고 있다고 했나요?…
# ⚠️  miss [9791165435134] 피부에는 어떤 색들이 있나요?…
# ⚠️  miss [9791165435134] 피부가 하는 일은 무엇일까요?…
# ⚠️  miss [9791165435134] 사람마다 피부색이 다른 이유는 무엇일까요?…
# ⚠️  miss [9791165435158] 젊은이는 바라던 대로 무엇이 되었나요?…
# ⚠️  miss [9791165435158] 젊은이가 바라던 것은 무엇이었을까요?…
# ⚠️  miss [9791165435202]  움직이지 못하는 말미잘에게 먹이를 주는 동물…
# ⚠️  miss [9791165435226] 마야는 비명을 지르며 어떻게 되었나요?…
# ⚠️  miss [9791165435226] 살타사우르스는 다른 목 긴 공룡들에 비하면 어…
# ⚠️  miss [9791165435233] 티고를 겁쟁이라고 한 이유는 무엇인가요?…
# ⚠️  miss [9791165435233] 공룡이 어렸을 때는 누가 먹이를 구해다 주나요…
# ⚠️  miss [9791165435233] 티라노사우루스의 알은 크기가 어느 정도였나요?…
# ⚠️  miss [9791165435233] 세상에서 제일가는 공룡은 무엇인가요?…
# ⚠️  miss [9791165435233] 티라노사우루스는 몇 킬로미터로 달리나요?…
# ⚠️  miss [9791165435240] 과일과 채소를 어떻게 하자고 했나요?…
# ⚠️  miss [9791165435257] 밥이 된 쌀은 어디에 올라갈까요?…
# ⚠️  miss [9791165435257] 벼는 어떤 색의 꽃을 피울까요?…
# ⚠️  miss [9791165435288] 공기는 어떤 역할을 하나요?…
# ⚠️  miss [9791165435288] 공기는 어디에 꼭 필요한가요?…
# ⚠️  miss [9791165435295] 하늘 높이 뛰어오를 수 있게 도와주는 용수철은…
# ⚠️  miss [9791165435301] 털모자로 어떤 행동을 하였나요?…
# ⚠️  miss [9791165435363] 아빠는 널빤지로 무엇을 했나요?…
# ⚠️  miss [9791165435363] 꼬마 쇠똥구리가 먹고 싶은 건 무엇인가요?…
# ⚠️  miss [9791165435400] 태양의 가족을 만나러 가는 마음은 어떤가요?…
# ⚠️  miss [9791165435455] 시계와 달력의 숫자를 무엇으로 바꾸고 있나요?…
# ⚠️  miss [9791165435530] 몸 색깔이 진한 신랑감들을 보고 딸은 어떻게 …
# ⚠️  miss [9791165435592] 거미왕은 손수건을 꺼내어 무엇을 하였나요?…
# ⚠️  miss [9791165435622] 망가진 물건들은 어떻게 했나요?…
# ⚠️  miss [9791165435622] 그림을 반으로 나누었을 때 반쪽이 사라진 것들…
# ⚠️  miss [9791165435622] 가장 좋아하는 망토를 나누려고 하자 포리는 어…
# ⚠️  miss [9791165435639] 가미와 야미는 준이를 어떻게 생각하나요?…
# ⚠️  miss [9791165435653] 검은색 말이 사라져 버린 장소는 어디인가요?…
# ⚠️  miss [9791165435653] 카멜레온이 물끄러미 바라보던 것은 무엇이었나요…
# ⚠️  miss [9791165435660] 땅이 작은 꽁꽁 왕국은 넓은 땅의 후끈 왕국을…
# ⚠️  miss [9791165435677] 모양에 따라 물건을 분류하고 난 다음에는 어떤…
# ⚠️  miss [9791165435677] 처음에 얼렁뚱땅 아저씨는 무엇에 따라 물건을 …
# ⚠️  miss [9791165435677] 얼렁뚱땅 아저씨는 물건을 정리한 후 무엇을 했…
# ⚠️  miss [9791165435714] 넓이가 멍석 여섯 개가 들어가는 곳은 어디인가…
# ⚠️  miss [9791165435714] 최 부자는 황 부자의 집보다 어디가 더 크다고…
# ⚠️  miss [9791165435714] 개똥이가 주인님 주인님 하며 부르자 최 부자는…
# ⚠️  miss [9791165437435] 악기가 될 만한 것들을 어떻게 했나요?…
# ⚠️  miss [9791165437435] 요정들은 가져온 것들을 어떻게 했나요?…
# ⚠️  miss [9791165437435] 며칠 뒤에 무슨일이 생길까요?…
# ⚠️  miss [9791165437442] 감이와 친구들이 모여서 무엇을 했나요?…
# ⚠️  miss [9791165437459] 네모를 차곡차곡 쌓아 동그라미를 올리면 어떻게…
# ⚠️  miss [9791165437459] 어디 위에 작은 네모를 쌓나요?…
# ⚠️  miss [9791165437466] 바퀴들이 넘어졌을 때 반응이 어땠나요? …
# ⚠️  miss [9791165437466] 아이를 안고 가느라 힘이 들어 보이는 엄마에게…
# ⚠️  miss [9791165437466] 사람들이 힘들어하고 있을 때 어떤 일이 생겼나…
# ⚠️  miss [9791165437473] 눈사람이 없어져셔 송이는 어떻게 했나요?…
# ⚠️  miss [9791165437473] 수수께끼 놀이를 하면 어떨까요?…
# ⚠️  miss [9791165437473] 엄마는 무엇을 하고 있나요?…
# ⚠️  miss [9791165437473] 송이가 눈사람을 보기 위해 어떻게 했나요?…
# ⚠️  miss [9791165437473] 아기가 울자 엄마는 무엇을 했나요?…
# ⚠️  miss [9791165437480] 나라가 아빠와 함께 놀다가 조그만 물웅덩이에 …
# ⚠️  miss [9791165437480] 나라는 보자기를 들춘 후에 무엇을 했나요?…
# ⚠️  miss [9791165958268] 어떤 물건의 양쪽이 똑같았나요?…
# ⚠️  miss [9791165958275] 무지개색 계단을 만나서 기분이 어땠나요?…
# ⚠️  miss [9791165958305] 우리가 먹은 것은 무엇인가요?…
# ⚠️  miss [9791165958459] 꼬미는 어디에 있었나요?…
# ⚠️  miss [9791165958473] 생일 선물로 무엇을 갖고 싶나요?…
# ⚠️  miss [9791165958497] 신데렐라는 누구를 불렀나요?…
# ⚠️  miss [9791188491278] 꼬마마녀는 배가 고파서 어떻게 했나요?…
# ⚠️  miss [9791188491292] 빤돌이는 어디에 살고 있나요?…
# ⚠️  miss [9791188491353] 온 세상을 환하고 따뜻하게 만드는 것은 무엇인…
# ⚠️  miss [9791190861021] 고양이 발톱을 보면 어떻게 느낄까요?…
# ⚠️  miss [9791190861021] 발톱으로 겁을 주는 고양이를 보면 어떨까요?…
# ⚠️  miss [9791190861021] 고양이는 언제 털갈이를 하나요?…
# ⚠️  miss [9791190861021] 고양이는 꼬리로 몸의 균형을 잡기 때문에 어디…
# ⚠️  miss [9791190861021] 꼬리로 몸의 균형을 잡기 때문에 높고 좁은곳에…
# ⚠️  miss [9791190861021] 고양이는 어디를 쑥 빠져나가나요?…
# ⚠️  miss [9791190861021] 사자나 호랑이 같은 고양잇과 동물이 빠르게 달…
# ⚠️  miss [9791190861113] 다른 암컷 타조들이 타나의 둥우리에 와서 알을…
# ⚠️  miss [9791190861113] 자그마했던 새끼들이 훌쩍 자란 건 얼마나 지난…
# ⚠️  miss [9791190861120] 바나나가 자라면 어떻게 되나요?…
# ⚠️  miss [9791190861120] 바나나를 우산으로 쓰면 좋은때는?…
# ⚠️  miss [9791190861137] 사과 껍질을 깎아 두면 속살이 갈색으로 변하는…
# ⚠️  miss [9791190861137] 과일 삼총사를 보고 무슨 생각을 했나요?…
# ⚠️  miss [9791190861144] 꽃받침이 영양분을 먹고 점점 부풀어 어떻게 되…
# ⚠️  miss [9791190861144] 작은 잎 세 장이 어디에 모여 났나요?…
# ⚠️  miss [9791190861144] 내가 만들었다고 한 이유는 무엇인가요?…
# ⚠️  miss [9791190861151] 아기 소는 크면 어떻게 바뀔까요?…
# ⚠️  miss [9791190861151] 송아지가 엄마 소랑 닮지 않았다고 한 이유는 …
# ⚠️  miss [9791190861151] 내가 두 발에 힘을 주고 발딱 일어섰을 때 엄…
# ⚠️  miss [9791190861168] 똑같은 기린들을 보면 어때?…
# ⚠️  miss [9791190861175] 겨울을 나기 위해서 다람쥐는 무엇을 만들어야 …
# ⚠️  miss [9791190861182] 보드랍고 가느다란 짧은 털로 덮여 있는 사슴뿔…
# ⚠️  miss [9791190861205] 아기를 밴 엄마 캥거루는 틈만 나면 왜 새끼 …
# ⚠️  miss [9791190861205] 엄마 캥거루는 엄마 곁을  떠나 새로운 곳으로…
# ⚠️  miss [9791190861229] 아기 코뿔소가 무엇을 하나요?…
# ⚠️  miss [9791190861229] 코뿔소들에게 또 무엇을 하자고 했나요?…
# ⚠️  miss [9791190861229] 먹이를 준 코뿔소들에게 어떤 마음이 들었나요?…
# ⚠️  miss [9791190861229] 엄마 코뿔소랑 아기 코뿔소랑 진흙에서 무엇을 …
# ⚠️  miss [9791190861267] 혼자서 살기 위해 날아가는 거미는?…
# ⚠️  miss [9791190861267] 무엇을 배에 붙이고 다니면서 지키는 거미도 있…
# ⚠️  miss [9791190861267] 먼지 주머니 속에 숨는 거미는?…
# ⚠️  miss [9791190861274] 밝은지 알고 싶거나 먹이를 찾고 싶을 때 달팽…
# ⚠️  miss [9791190861274] 달팽이가 밝고 어두운 정도를 알고 냄새를 맞을…
# ⚠️  miss [9791190861274] 달팽이는 몸에 촉촉하게 물기가 있으면 어떤 장…
# ⚠️  miss [9791190861274] 알에서 새끼 달팽이가 나오나요 걸리는 시간은 …
# ⚠️  miss [9791190861335] 고래의 물기둥은 어떻게 만들어지나요?…
# ⚠️  miss [9791190861366] 새끼 악어가 잠자리를 어떻게 했나요?…
# ⚠️  miss [9791190861366] 악어는 햇빛을 쬐다 더우면 어디로 들어가나요?…
# ⚠️  miss [9791190861366] 얼룩말을 한입에 덥석 한 동물은 무엇인가요?…
# ⚠️  miss [9791190861366] 악어들이 싸움을 할 때 어떻게 움직이나요?…
# ⚠️  miss [9791190861427] 엄마와 함께 내게 먹이를 물어다 주는 이는 누…
# ⚠️  miss [9791190861427] 알에서 깬 아기 수리는 어떻게 했나요?…
# ⚠️  miss [9791190861427] 날개를 쫙 편 수리의 모습은 어때요?…
# ⚠️  miss [9791190861427] 수리는 먹이를 어떻게 먹나요?…
# ⚠️  miss [9791190861441] 둥지의 주인은 누구죠?…
# ⚠️  miss [9791190861472] 결투에서 이긴 장수풍뎅이도, 결투에서 진 사슴…
# ⚠️  miss [9791190861472] 왕사슴벌레의 성격은 어떤가요?…
# ⚠️  miss [9791190861472] 사슴벌레들은 무엇을 좋아하나요? …
# ⚠️  miss [9791190861496] 나는 알을 어디에 낳았을까요?…
# ⚠️  miss [9791190861496] 애벌레가 번데기가 된 지 며칠 후 어떤 일이 …
# ⚠️  miss [9791190861502] 애벌레가 허물을 벗더니 어떻게 되었나요?…
# ⚠️  miss [9791190861519] 허물을 한번 벗고 몸이 조금 더 커지고 드디어…
# ⚠️  miss [9791190861564] 옥수수 수꽃은 어디에서 피나요?…
# ⚠️  miss [9791190861564] 이제 곧 옥수수를 먹는다며 좋아하게 된 것은 …
# ⚠️  miss [9791190861564] 아침에 일어나면 얼마나 자랐나, 옥수수랑 무슨…
# ⚠️  miss [9791190861588] 동글 납작한 아기 감은 어디에 불쑥 생기나요?…
# ⚠️  miss [9791190861595] 호박의 주황 속살을 파내어 무엇을 만드나요?…
# ⚠️  miss [9791190861601] 배추 싹이 가을 햇빛을 받으며 넓적넓적 어떻게…
# ⚠️  miss [9791190861632] 상수리나무의 도토리 모자는 어떻게 생겼나요?…
# ⚠️  miss [9791190861649] 민들레꽃은 무엇으로 이루어져 있나요?…
# ⚠️  miss [9791190861649] 꽃이 지고 꽃대도 쓰러지고 나서 민들레에겐 어…
# ⚠️  miss [9791190861656] 해바라기씨를 심었더니 싹이 나온 후 무엇이 보…
# ⚠️  miss [9791190861663] 나는 어떻게 해서 잠에서 깼나요?…
# ⚠️  miss [9791190861724] 암나무에 열린 열매에서 무슨 냄새가 났나요?…
# ⚠️  miss [9791190861724] 꽃가루는 바람을 타고 암꽃을 향해 어떻게 갔을…
# ⚠️  miss [9791190861724] 추운 겨울에 겨울눈 속에 무엇을 하고 있다 봄…
# ⚠️  miss [9791190861724] 봄이 되어 피어난 수꽃이 쑥쑥 자라면 무엇을 …
# ⚠️  miss [9791190861724] 무엇을 보면 알 수 있을까요?…
# ⚠️  miss [9791190861724] 가지가 어느 곳을 향해 쭉쭉 뻗으면 남자 나무…
# ⚠️  miss [9791190861724] 은행나무에 잎사귀를 보고 무엇을 알 수 있을까…
# ⚠️  miss [9791190861724] 탱글탱글한 초록 열매가 쭈글쭈글 누렇게 익어 …
# ⚠️  miss [9791190861724] 암수 종류나 나이와 상관없이 은행나무는 모두 …
# ⚠️  miss [9791190861748] 고래 똥은 물속에서 어떻게 되는 똥인가요?…
# ⚠️  miss [9791197046216] 멍멍개는 무엇을 하고 있나요?…
# ⚠️  miss [9791197046216] 수캐는 어떻게 오줌을 누나요?…
# ⚠️  miss [9791197046216] 멍멍개는 무엇을 하려고 하나요?…
# ⚠️  miss [9791197046216] 하루 중 어느 때일까요?…
# ⚠️  miss [9791197046216] 멍멍개는 무엇을 하고 있나요?…
# ⚠️  miss [9791197046254] 얼씬도 하지 말라고 한 곳은 어디인가요?…
# ⚠️  miss [9791197046254] 곰이 사람처럼  하는 행동에는 무엇이 있나요?…
# ⚠️  miss [9791197046292] 호랑이는 먹잇감에 가까워지자 무엇을 했나요?…
# ⚠️  miss [8975253570] 이히체크가 웃지 못한 이유는 무엇일까요?…
# ⚠️  miss [8975253570] 어머니는 화를 내면서 무슨 말씀을 하셨나요?…
# ⚠️  miss [8975253570] 아침에 일어나면 무엇을 하라고 했나요?…
# ⚠️  miss [8975253570] 한숨을 내쉬고 어떤 말을 했나요?…
# ⚠️  miss [8975253570] 조샤는 수프를 어떻게 한다고 말했나요?…
# ⚠️  miss [8975253570] 이히체크는 누구였다면 실컷 웃었을 것으로 생각…
# ⚠️  miss [8975253570] 남자아이는 반코트의 단추를 어떻게 끼웠나요?…
# ⚠️  miss [8975253570] 먹거나 마시지 않는 대신 웃지 않으면 살아갈 …
# ⚠️  miss [8975253570] 바늘처럼 작은 것은 누구인가요?…
# ⚠️  miss [8975253570] 이히체크는 날개에 단단히 매달리면서 무엇이라고…
# ⚠️  miss [8975253570] 누구를 데리고 다닌다고 하였나요?…
# ⚠️  miss [8975253570] 물 속에서 허우적거린 것은 누구일까요?…
# ⚠️  miss [8975253570] 튀어나온 것은 무엇일까요?…
# ⚠️  miss [8975253570] 이히체크는 어디에서 잠들었나요?…
# ⚠️  miss [8975253570] 배가 어떻게 되었나요?…
# ⚠️  miss [8975253570] 투덜쟁이는 침대 위에 큰 스카프를 펴고 무엇을…
# ⚠️  miss [8975253570] 이히체크는 얼마 동안 그대로 계속 지냈나요?…
# ⚠️  miss [8975253570] 이히체크는 얄미운 듯 아다 씨를 흘겨본 다음 …
# ⚠️  miss [8975253570] 발소리가 들려 온 곳은 어디일까요?…
# ⚠️  miss [8975253570] 자기만큼이나 큰 솔방울을 굴린다는 것은 어떤 …
# ⚠️  miss [8975253570] 무엇이 신경이 쓰였나요?…
# ⚠️  miss [8975253570] 맨 아래 아이는 울면서 어떤 말을 했나요?…
# ⚠️  miss [8975253570] 자기 모습을 보고 놀란 떼쟁이는 어떻게 행동했…
# ⚠️  miss [8975253570] 어머니는 아무 말도 하지 않고 어떻게 했나요?…
# ⚠️  miss [8975253570] 조샤가 당근을 하나도 남기지 않고 다 먹는 것…
# ⚠️  miss [8975253570] 어린 까마귀는 누구 때문에 화가 나 있었을까요…
# ⚠️  miss [8975253570] 이히체크가 크게 웃자 어떤 일이 생겼나요?…
# ⚠️  miss [8975253570] 카샤는 무슨 소리를 듣고 눈을 떴나요?…
# ⚠️  miss [8975253570] 바람은 이히체크가 무엇을 할 수 있도록 도와주…
# ⚠️  miss [8975253570] 이히체크는 스커트를 타고 내려와 어디로 갔나요…
# ⚠️  miss [8975253570] 화를 내라고 울부짖은 것은 누구일까요?…
# ⚠️  miss [8975253570] 이히체크가 지내려고 하는 곳은 어디일까요?…
# ⚠️  miss [8975253570] 누구 때문에 이렇게 된 것일까요?…
# ⚠️  miss [8975253570] 이 아이는 찬찬하지 못한 덜렁이라고 말한 것은…
# ⚠️  miss [8975253570] 떼쟁이는 연필을 어떻게 하였나요?…
# ⚠️  miss [8975253570] 할머니가 걸어온 곳은 어디일까요?…
# ⚠️  miss [8975253627] 누가 두 마리였나요?…
# ⚠️  miss [8975253627] 오티스는 뭐 하면서 말했나요?…
# ⚠️  miss [8975253627] 어김없이 제 자리에 붙어 있는 것은 무엇일까요…
# ⚠️  miss [8975253627] 오티스의 설명은 무엇을 바꾸지 못했을까요?…
# ⚠️  miss [8975253627] 오티스는 다리가 아픈 상황에서 무엇을 하고 있…
# ⚠️  miss [8975253627] 오티스는 교실 안이 떠들썩해지기를 기다려서 무…
# ⚠️  miss [8975253627] 재컬리 테일러 고등학교에서 오티스는 어떤 영웅…
# ⚠️  miss [8975253627] 선생님은 매트를 우리에서 꺼낸 다음 무엇을 했…
# ⚠️  miss [8975253627] 선생님은  핑키를 가지고 무엇을 했나요?…
# ⚠️  miss [8975253627] 둘은 어떻게 응원했나요?…
# ⚠️  miss [8975253627] 둘은 뭘 했나요?…
# ⚠️  miss [8975253627] 스튜이가 귀찮게 굴어서 오티스는 무엇을 생각했…
# ⚠️  miss [8975253627] 스튜이가 읽으면 어떻게 되나요?…
# ⚠️  miss [8975253627] 선생님이 나중에 생각하자고 말하면서 무엇을 했…
# ⚠️  miss [8975253627] 오티스는 우울하게 말하면서 뭘 했나요?…
# ⚠️  miss [8975253627] 오티스는 배고파하면서 뭘 했나요?…
# ⚠️  miss [8975253627] 아주머니는 어떻게 하고 계신가요?…
# ⚠️  miss [8975253627] 어젯저녁에 저하고 아빠가 동생을 데리고 공원으…
# ⚠️  miss [8975253635] 할 일이 있어서 무엇을 해야하나요?…
# ⚠️  miss [8975253635] 에디는 무엇을 좋아하나요?…
# ⚠️  miss [8975253635] 머티는 철사 끝을 무엇에 넣었나요?…
# ⚠️  miss [8975253635] 무엇이 여러 달 동안이나 마을의 이야깃거리였나…
# ⚠️  miss [8975253635] 할머니는 할아버지 사과나무에 운석이 떨어지지 …
# ⚠️  miss [8975253635] 에디가 사과밭으로 간 것은 언제일까요? …
# ⚠️  miss [8975253694] 안디는 할머니 방의 창문 밑으로 가서 어떤 행…
# ⚠️  miss [8975253694] 안디는 울타리로 기어나와 어디로 다가갔나요?…
# ⚠️  miss [8975253694] 할머니는 안디에게 뭐라고 칭찬했나요?…
# ⚠️  miss [8975253694] 할머니는 난처하다는 듯 어떤 행동을 했나요?…
# ⚠️  miss [8975253694] 베로는 옆에서 지켜보다가 어떻게 했나요?…
# ⚠️  miss [8975253694] 바쁜 할머니는 무슨 일을 계속하고 있었나요?…
# ⚠️  miss [8975253694] 안디는 어디에 서 있었나요?…
# ⚠️  miss [8975253694] 자동차와 그 남자가 부딪힐 때 할머니의 반응은…
# ⚠️  miss [8975253694] 심술 사납게 두 사람을 바라본 사람은 누구인가…
# ⚠️  miss [8975253694] 안디는 새장과 어항을 어떻게 했나요?…
# ⚠️  miss [8975253694] 언제 베란다의 지붕을 때리는 빗소리가 마치 식…
# ⚠️  miss [8975253694] 식구들은 어디에 빵부스러기를 놓아주었나요?…
# ⚠️  miss [8975253694] 언제 안디는 학교가 끝나기만을 애타게 기다렸나…
# ⚠️  miss [8975253694] 게르하르트의 할머니는 어디에 절대 타지 않나요…
# ⚠️  miss [8975253694] 누가 꼬마를 불렀나요?…
# ⚠️  miss [8975253694] 안디는 사 온 물건들을 어디에서 꺼냈나요?…
# ⚠️  miss [8975253694] 누군가가 안디를 뭐라고 부르는 소리를 들었나요…
# ⚠️  miss [8975253694] 금테 둘린 접시는 어디에 있던 접시인가요?…
# ⚠️  miss [8975253694] 할머니는 모든 식구가 잠든 뒤 무엇을 했다고 …
# ⚠️  miss [8975253694] 누구네 집 현관문은 열려 있었나요?…
# ⚠️  miss [8975253694] 안디는 뭘 해주겠다고 말했나요?…
# ⚠️  miss [8975253694] 할머니는 파이프를 빨아 무엇을 내뿜었나요?…
# ⚠️  miss [8975253694] 안디는 어머니를 어떻게 따라갔나요?…
# ⚠️  miss [8975253694] 안디는 새 할머니를 도와줄 수 있어서 어떻다고…
# ⚠️  miss [8975253694] 안디는 무엇이 아직 늦지 않았다고 했나요?…
# ⚠️  miss [8975253694] 안디는 접시와 장미를 어떻게 했나요?…
# ⚠️  miss [8975253694] 누가 꼬챙이에 분홍색 솜사탕을 감고 있었나요?…
# ⚠️  miss [8975253694] 두 사람은 소시지와 솜사탕을 어떻게 했나요?…
# ⚠️  miss [8975253694] 할머니가 안디에게 이젠 돌아가고 싶냐고 물었을…
# ⚠️  miss [8975253694] 침대 밑에서 나는 소리를 들은 안디는 어떤 행…
# ⚠️  miss [8975253694] 크리스톨의 겉모습은 어땠나요?…
# ⚠️  miss [8975253694] 안디는 무슨 일은 아무것도 아니라고 생각했나요…
# ⚠️  miss [8975253694] 어머니는 바느질감을 가지고 와서 어떻게 했나요…
# ⚠️  miss [8975253694] 저쪽 앞에 보이는 검은 말은 무엇을 하고 있었…
# ⚠️  miss [8975253694] 하나님은 어떤 사람들을 용서해 준다고 했나요?…
# ⚠️  miss [8975253694] 여느 날의 할머니가 되는 구나라고 말한 할머니…
# ⚠️  miss [8975253694] 부인의 무서운 얼굴을 본 안디는 어떤 반응을 …
# ⚠️  miss [8975253694] 크리스톨은 어떤 행동을 하며 안디를 데리고 갔…
# ⚠️  miss [8975253694] 어머니의 뽀뽀를 받으며 안디는 뭐라고 말했나요…
# ⚠️  miss [8975253694] 언제 또 비가 왔나요?…
# ⚠️  miss [8975253694] 베로는 방안에서 무엇을하고 있나요?…
# ⚠️  miss [8975253694] 누가 모자를 벗고 인사를 했나요?…
# ⚠️  miss [8975253694] 안디는 낡은 양말을 어디 속에 꾸겨 넣으려고 …
# ⚠️  miss [8975253694] 안디는 곰곰히 생각하며 어디로 갔나요?…
# ⚠️  miss [8975253694] 안디는 침대 밑에서 더 큰소리로 으르렁거리는 …
# ⚠️  miss [8975253694] 놀이터에서 뚱뚱한 할머니는 무엇을 하고 있었나…
# ⚠️  miss [8975253694] 종이로 만든 우스꽝스러운 남자 머리는 어떻게 …
# ⚠️  miss [8975253694] 할머니는 무엇을 들고 있었나요?…
# ⚠️  miss [8975253694] 할머니는 한 발짝 더 가까이 다가가 어디 사이…
# ⚠️  miss [8975253694] 할머니의 말을 듣고 안디는 어떻게 행동했나요?…
# ⚠️  miss [8975253694] 오늘은 무엇을 하기 좋은 날씨인가요?…
# ⚠️  miss [8975253716] 행크는 어떤 일이 생각나서 어떤 기분이 들었나…
# ⚠️  miss [8975253716] 교장선생님은 어디에 앉아 있나요?…
# ⚠️  miss [8975253716] 행크는 뭐라고 외쳤나요?…
# ⚠️  miss [8975253716] 선생님은 무엇을 했나요?…
# ⚠️  miss [8975253716] 마음속으로 안 되겠다고 생각하면서 어떻게 하면…
# ⚠️  miss [8975253716] 행크는 가다가 어떤 말을 들었나요?…
# ⚠️  miss [8975253716] 학교에서 뱀을 기를 수 없다고 말한 사람은 누…
# ⚠️  miss [8975253716] 여학생들은 어떤 반응이었나요?…
# ⚠️  miss [8975253716] 행크는 무엇을 했나요?…
# ⚠️  miss [8975253716] 어머니가 거들떠보지도 않는 것은 무엇인가요?…
# ⚠️  miss [8975253716] 행크는 가지고 가는 선물을 무엇이라고 설명하였…
# ⚠️  miss [8975253716] 행크는 어떤 반응을 보였나요?…
# ⚠️  miss [8975253716] 소리의 정체는 무엇이었나요?…
# ⚠️  miss [8975253716] 행크는 언제나 얼마짜리 은화를 받았나요?…
# ⚠️  miss [8975253716] 행크는 리즈 누나의 통화를 듣고 어땠나요?…
# ⚠️  miss [8975253716] 행크는 마침내 무엇을 했나요?…
# ⚠️  miss [8975253716] 학교에 누가 온다고 했나요?…
# ⚠️  miss [8975253716] 오투르 아저씨는 어디에 있었나요?…
# ⚠️  miss [8975253716] 행크가 히죽 웃은 이유는 무엇인가요?…
# ⚠️  miss [8975253716] 행크는 어떤 이야기를 해주었나요?…
# ⚠️  miss [8975253716] 셋은 어디로 들어갔나요?…
# ⚠️  miss [8975253716] 학교에서 뱀을 기르는 일은 어떻다고 하였나요?…
# ⚠️  miss [8975253716] 행크는 가게로 가는 동안 어떤 마음이었나요?…
# ⚠️  miss [8975253716] 행크는 과학실에서 무엇을 했나요?…
# ⚠️  miss [8975253724] 누가 맥주를 마시고 있었나요?…
# ⚠️  miss [8975253724] 어린 꼬마여서 좋지만은 않지만 그래도 어떻다고…
# ⚠️  miss [8975253724] 왜 나는 아무 생각도 할 수 없게 되었어요?…
# ⚠️  miss [8975253724] 대장간 아저씨는 무엇을 좋아하나요?…
# ⚠️  miss [8975253724] 바르디노는 한 장난꾸러기가 서커스를 어떻게 만…
# ⚠️  miss [8975253724] 남자는 자신이 정말 무엇이라고 했나요?…
# ⚠️  miss [8975253724] 남자는 자신이 누구라고 했나요?…
# ⚠️  miss [8975253724] 보물을 파내 주면 어떻게 한다고 꾸며 냈어요?…
# ⚠️  miss [8975253724] 말하지 않겠다며 오를라가 나에게 어떻게 했어요…
# ⚠️  miss [8975253724] 드디어 풍차 방앗간에 다다르고 오를라가 어떻게…
# ⚠️  miss [8975253724] 나무가 어느 쪽으로 구부러졌나요?…
# ⚠️  miss [8975253724] 누가 가장 좋은 입장권을 나에게 주었나요?…
# ⚠️  miss [8975253724] 나는 등골이 어떻게 됐나요?…
# ⚠️  miss [8975253724] 오를라가 망토를 향하여 달려들어 나는 어떻게 …
# ⚠️  miss [8975253724] 미스터 스트롱은 어디에 있었나요?…
# ⚠️  miss [8975253724] 미스터 스트롱은 쇠막대를 집어 던진 후에는 어…
# ⚠️  miss [8975253724] 어떤 사람이면 오를라를 잡아다 혼내 줄 수 있…
# ⚠️  miss [8975253724] 누가 나에게 부탁했나요?…
# ⚠️  miss [8975253724] 마지막으로 누가 나오나요?…
# ⚠️  miss [8975253724] 누가 큼직한 대포를 끌고 나왔나요?…
# ⚠️  miss [8975253724] 오를라는 나를 어떻게 불렀나요?…
# ⚠️  miss [8975253724] 대장간 뒤뜰에서 나무에 올라앉아 무엇을 할 수…
# ⚠️  miss [8975253724] 누가 나 있는 쪽으로 왔나요?…
# ⚠️  miss [8975253724] 나는 번개같이 어떤 좋은 생각이 떠올랐나요?…
# ⚠️  miss [8975253724] 누가 다치지 않는다고 했나요?…
# ⚠️  miss [8975253724] 무엇이 걱정됐나요?…
# ⚠️  miss [8975253724] 아저씨의 험악한 기세에 오를라는 어떻게 했나요…
# ⚠️  miss [8975253724] 상자를 닫으려던 나는 무엇을 발견했나요?…
# ⚠️  miss [8975253724] 내가 계속 모르는 체하니 오를라는 어떻게 반응…
# ⚠️  miss [8975253724] 어떤 개가 있었던 상자인가요?…
# ⚠️  miss [8975253724] 동그란 구멍이 뚫려 있는 상자 쪽으로 몰래 다…
# ⚠️  miss [8975253724] 오를라가 찾는 아이를 어떻게 표현하고 있나요?…
# ⚠️  miss [8975253724] 오를라에게 보물을 파내라고 누가 말해 줬나요?…
# ⚠️  miss [8975253724] 채찍을 울리자, 말들은 무용 선생님처럼 어떻게…
# ⚠️  miss [8975253724] 빨리 달아나기 위해 나는 어떻게 했나요?…
# ⚠️  miss [8975253724] 두 사람이 악수하니 손님들 사이에서 어떤 소리…
# ⚠️  miss [8975253724] 누가 뒤를 이를 사람이 필요했나요?…
# ⚠️  miss [8975253724] 어떻게 하는 동안에 좋은 생각이 떠올랐나요?…
# ⚠️  miss [8975253724] 대답하는 대신 무슨 행동을 하였나요?…
# ⚠️  miss [8975253724] 나는 오를라를 어떤 녀석이라고 했나요?…
# ⚠️  miss [8975253724] 다시 텐트 안으로 돌아가 어디로 숨었어요?…
# ⚠️  miss [8975253724] 나를 찾고 있는 거라면 야콥은 어떻게 하면 된…
# ⚠️  miss [8975253724] 언제 고깃간 집 개와 부딪칠 뻔했나요?…
# ⚠️  miss [8975253724] 지렁이를 잡으라고 말하고는 대장간 아저씨는 무…
# ⚠️  miss [8975253724] 누가 어서 가서 서커스를 보라고 말했나요?…
# ⚠️  miss [8975253724] 누가 내 말을 들어주려고도 하지 않았나요?…
# ⚠️  miss [8975253724] 어떻게 했더니 대포 왕에게 받을 수 있었나요?…
# ⚠️  miss [8975253724] 나는 오를라에게 어떻게 불렸나요?…
# ⚠️  miss [8975253724] 오를라가 어떻게 되어버린다고 상상했나요?…
# ⚠️  miss [8975253724] 나는 아무 대답도 하지 않고 어떻게 했나요?…
# ⚠️  miss [8975253724] 그림엽서나 사진에는 어떤 일이 없어요?…
# ⚠️  miss [8975253724] 내가 본 그 수레는 코끼리가 체조하는 것처럼 …
# ⚠️  miss [8975253724] 오를라가 나타나서 소리 내 울고 싶었던 그때 …
# ⚠️  miss [8975253724] 나는 오를라의 모습을 보고 무엇을 알 수 있었…
# ⚠️  miss [8975253724] 텐트 입구 위에는 무엇이 반짝거리고 있었나요?…
# ⚠️  miss [8975253724] 한 남자가 요술사가 어떠하다고 했나요?…
# ⚠️  miss [8975253724] 누가 대포에서 뛰어 내렸나요?…
# ⚠️  miss [8975253724] 가장 가까운 텐트에 어떻게 들어갔나요?…
# ⚠️  miss [8975253724] 어떻게 하면 나를 잡을 수 없게 하나요?…
# ⚠️  miss [8975253724] 그때 눈에 띄인것은 무엇인가요?…
# ⚠️  miss [8975253724] 나는 잠깐 누구의 뒷모습을 보고 있었나요?…
# ⚠️  miss [8975253724] 올센 부인은 자신을 늙은 할머니라 부른 게 화…
# ⚠️  miss [8975253724] 아저씨는 차렷 자세를 취한 후 어떻게 했나요?…
# ⚠️  miss [8975253724] 이제부터는 무얼 하고 놀자고 하나요?…
# ⚠️  miss [8975253724] 양배추밭에 가서는 무얼 하면 신난다고 해요?…
# ⚠️  miss [8975253724] 누가 대장간 아저씨와 미스터 스트롱에게 지혜가…
# ⚠️  miss [8975254623] 여름을 가져다주는 새가 뭐냐고 물은 건 누구인…
# ⚠️  miss [8975254623] 슬기로운 곰들이 바꾸어가면서 맡은 일을 올해는…
# ⚠️  miss [8975254623] 가이는 바다 위에 떠올라 무엇을 했나요?…
# ⚠️  miss [8975254623] 엄마펭귄은 번들거리는 눈으로 무엇을 했나요?…
# ⚠️  miss [8975254623] 미시카의 목에는 무엇이 감겨져 있었나요?…
# ⚠️  miss [8975254623] 무시카가 엄마에게 무슨 행동을 했나요?…
# ⚠️  miss [8975254623] 유리를 살릴 수 있었던 이유는 무엇일까요?…
# ⚠️  miss [8975254623] 룰루때문에 우쭐해진 임금님펭귄은 어떻게 했나요…
# ⚠️  miss [8975254623] 미시카가 손으로 가리킨 곳은 어디인가요?…
# ⚠️  miss [8975254623] 룰루 아기를 잃어버리고 만 이유는 무엇일까요?…
# ⚠️  miss [8975254623] 또 한패의 손님이 타고 있었던 것은 무엇인가요…
# ⚠️  miss [8975254623] 너희들은 이제 곧 어른이 된다고 말한 것은 누…
# ⚠️  miss [8975254623] 무서운 괴물이 아기들은 어떤가요?…
# ⚠️  miss [8975254623] 미시카는 무엇을 입에 물고 있었나요?…
# ⚠️  miss [8975254623] 누가 틀림없이 나에게 고맙다고 할까요?…
# ⚠️  miss [8975254623] 미시카와 오라는 무시카가 멀리서 보고 알 수 …
# ⚠️  miss [8975254623] 뭍 위의 어두운 하늘에 무엇이 보이기 시작했나…
# ⚠️  miss [8975254623] 여름 잔치의 즐거움을 날려 버린 것은 무엇인가…
# ⚠️  miss [8975254623] 큰 곰의 바위 꼭대기로 올라간 것은 누구인가요…
# ⚠️  miss [8975254623] 룰루가 끼끼의 발을 꽉 밟아 준 이유는 무엇일…
# ⚠️  miss [8975254623] 타야우트는 무엇을 하면서 다음해 여름을 생각했…
# ⚠️  miss [8975254623] 삼키려 해도 흐느낌이 치밀어 올랐지만 미시카는…
# ⚠️  miss [897525464] 그가 맡겨져 보호를 받으며 산 곳은 어디였나요…
# ⚠️  miss [897525464] 그가 세상을 떠난 직접적인 병명은 무엇이었나요…
# ⚠️  miss [897525464] 이시는 일어나 어떤 행동을 했나요?…
# ⚠️  miss [897525464] 사루도가 먹기 위해서 하는 일은 무엇인가요?…
# ⚠️  miss [897525464] 주인공보다 어린 여자아이는 누구인가요?…
# ⚠️  miss [897525464] 풀밭에 장난치고 노는 동물은 누구인가요?…
# ⚠️  miss [897525464] 티마위의 반응을 본 이시는 어떤 행동을 했나요…
# ⚠️  miss [897525464] 엄마가 태어난 장소는 어디인가요?…
# ⚠️  miss [897525464] 할아버지와 할머니보다 훨씬 옛날에 이 땅에 왔…
# ⚠️  miss [897525464] 흙 속에서 잠자고 있던 것은 무엇인가요?…
# ⚠️  miss [897525464] 어머니가 어느 곳에서 계절이 바뀌는 것을 알았…
# ⚠️  miss [8975254666] 상처를 입은 요한네스는 어떻게 되었나요?…
# ⚠️  miss [8975254666] 새 무기를 갖춘 것은 누구인가요?…
# ⚠️  miss [8975254666] 이런 말을 하는 것은 어떤 마음인가요?…
# ⚠️  miss [8975254666] 이 집은 어떤 상태라고 하나요?…
# ⚠️  miss [8975254666] 15분쯤 지난 뒤 벤은 무엇을 했나요?…
# ⚠️  miss [8975254666] 얀이 몰래 밝힌 것은 무엇인가요?…
# ⚠️  miss [8975254666] 도이칠란트 국민들은 마지못해서 무엇을 한 사람…
# ⚠️  miss [8975254666] 키가 후리후리하고 어깨가 딱 벌어진 사람은 누…
# ⚠️  miss [8975254666] 우리는 아직 소년단이 아니지만 무엇을 하기로 …
# ⚠️  miss [8975254666] 지구 교회에서는 무슨 일을 하고 있나요?…
# ⚠️  miss [8975254666] 프리체는 어떤 행동을 하며 말했나요?…
# ⚠️  miss [8975254666] 나는 뭐라고 칭찬했나요?…
# ⚠️  miss [8975254666] 벤에게 무엇을 가지라고 했나요?…
# ⚠️  miss [8975254666] 스웨덴 적십자사의 무슨 신청이 허락되었나요?…
# ⚠️  miss [8975254666] 교실 여기저기에 누가 있었나요?…
# ⚠️  miss [8975254666] 와이셔츠를 입은 사나이는 어떤 목소리로 말했나…
# ⚠️  miss [8975254666] 점령군은 왜 네덜란드 남자를 징집했나요?…
# ⚠️  miss [8975254666] 우쭐대는 관리들은 웃옷에 무엇을 달고 있었나요…
# ⚠️  miss [8975254666] 선생님은 언제 벤에게 말을 걸었나요?…
# ⚠️  miss [8975254666] 시내 근처에 도착한 포케는 어떻게 걸었나요?…
# ⚠️  miss [8975254666] 무엇을 하는 시간이었나요?…
# ⚠️  miss [8975254666] 방위대원이 어디에 나타나면 마을 사람들이 숨어…
# ⚠️  miss [8975254666] 벤과 얀은 안전하다는 소식이 있을 때까지 어떻…
# ⚠️  miss [8975254666] 라디오는 드디어 내일 밤에 무슨 일이 있을 거…
# ⚠️  miss [8975254666] 내일 밤 벰스테르에 비행기가 날아가 무엇을 한…
# ⚠️  miss [8975254666] 도이칠란트 병들이 총에 맞은 두 사람을 어떻게…
# ⚠️  miss [8975254666] 편지 뒷장의 속기문에 뭐라고 쓰여 있었나요?…
# ⚠️  miss [8975254666] 포케의 편지 속에 어머니에게 전하는 어떤 내용…
# ⚠️  miss [8975254666] 갇혀 있는 남자들은 내일 아침 7시 무엇을 한…
# ⚠️  miss [8975254666] 네덜란드에 도이칠란트 비행기가 불시착했을 때는…
# ⚠️  miss [8975254666] 벤과 얀은 언제 집으로 돌아갔나요?…
# ⚠️  miss [8975254666] 도이칠란트 군은 어디를 지나서 네덜란드로 쳐들…
# ⚠️  miss [8975254666] 신문에 수용소의 상태는 어떻다고 나왔나요?…
# ⚠️  miss [8975254666] 어머니에게 무엇을 알려 드라고 했나요?…
# ⚠️  miss [8975254666] 네덜란드 나치스당은 1940년 당 안에 무엇을…
# ⚠️  miss [8975254666] 무엇을 위한 특별 재판이 열렸나요?…
# ⚠️  miss [8975254666] 네덜란드 나치스 당원들은 왜 돌아다녔나요?…
# ⚠️  miss [8975254666] 신문에서는 어떤 거짓 기사를 내고 있었나요?…
# ⚠️  miss [8975254852] 나는 무엇이 나를 덮쳤다고 말했나요?…
# ⚠️  miss [8975254852] 누가 장난스러운 눈으로 나를 바라보았나요?…
# ⚠️  miss [8975254852] 어떤 송신기로 시험해 보기로 했나요?…
# ⚠️  miss [8975254852] 누가 악수를 청했나요?…
# ⚠️  miss [8975254852] 오늘은 누구를 찾아갔었다고 말했나요?…
# ⚠️  miss [8975254852] 밤의 키 당번은 반드시 허리에 무엇을 두르나요…
# ⚠️  miss [8975254852] 지금 국무회의를 하는 사람은 누구인가요?…
# ⚠️  miss [8975254852] 축하 잔치는 언제까지 계속 되었나요?…
# ⚠️  miss [8975254852] 오두막 안엔 무엇으로 꽉 차있나요?…
# ⚠️  miss [8975254852] 나는 뗏목으로 가서 마지막으로 어딜 둘러 보았…
# ⚠️  miss [8975254852] 내 말을 대통령에게 통역해 주는 사람은 누구인…
# ⚠️  miss [8975254852] 불빛을 향해 우리는 큰 소리로 외치며 작은 칸…
# ⚠️  miss [8975254852] 나는 누구에게 부탁했나요?…
# ⚠️  miss [8975254852] 비라코차의 본디 이름은 무엇인가요?…
# ⚠️  miss [8975254852] 항해를 시작한 지 45일이 지났을 때 뗏목은 …
# ⚠️  miss [8975254852] 암초의 빈틈을 향하고 있을 때 어떤 신호가 보…
# ⚠️  miss [8975254852] 어디에 미생물이 붙었나요?…
# ⚠️  miss [8975254852] 우리의 탐험에 필요한 것은 무엇이고 빌려주게 …
# ⚠️  miss [8975254852] 수염 기른 백색인종이 만들어 낸 신비로운 문명…
# ⚠️  miss [8975254852] 채석장에는 부싯돌처럼 단단한 무엇이 여기저기 …
# ⚠️  miss [8975254852] 페루의 조각가들이나 이스터섬의 조각가들은 어떤…
# ⚠️  miss [8975254852] 무엇에 가만히 앉아 있으면 버석버석 우둑우둑하…
# ⚠️  miss [8975254852] 과학자들은 뱀물고기를 무엇이라고 부르나요?…
# ⚠️  miss [8975254852] 오두막 안에는 무엇을 넣은 상자 2개가 놓여 …
# ⚠️  miss [8975254852] 동쪽에서 온 사람들은 귓불에 추를 달아 귀를 …
# ⚠️  miss [8975254852] 이 세상에서 우리가 무사하다는 것을 알고 있는…
# ⚠️  miss [8975254852] 코프라는 무엇인가요?…
# ⚠️  miss [8975254852] 닻을 내렸지만 왜 헛일이었나요?…
# ⚠️  miss [8975254852] 무엇이 고물의 키 있는 곳을 지나 한 줄로 나…
# ⚠️  miss [8975254852] 그 순간 큰 파도가 무엇을 덮치고 들어왔나요?…
# ⚠️  miss [8975254852] 밀림으로 내려가려면 어디로 가야 하나요?…
# ⚠️  miss [8975254925] 마르셀리노는 뭐라고 혼잣말을 중얼거렸나요?…
# ⚠️  miss [8975254925] 마르셀리노는 문을 가만히 밀고 나서 무엇을 했…
# ⚠️  miss [8975254925] 사람이 그리스도 님과 이야기할 수 있는 것은 …
# ⚠️  miss [8975254925] 무엇을 한 지도 벌써 2주일이나 지났나요?…
# ⚠️  miss [8975254925] 마르셀리노는 주머니에 먹을 것을 잔뜩 집어넣고…
# ⚠️  miss [8975254925] 빵죽 아저씨는 어떤 마음을 먹었나요?…
# ⚠️  miss [8975254925] 마르셀리노가 늘 무엇을 했나요?…
# ⚠️  miss [8975254925] 그리스도는 뭐라고 말했나요?…
# ⚠️  miss [8975254925] 그리스도는 어느 날 빙그레 웃으며 마르셀리노에…
# ⚠️  miss [8975254925] 빵만 한 사람 몫이 없어진 이유는 무엇인가요?…
# ⚠️  miss [8975254925] 성 프란체스코의 날이 다가오면 하느님을 위해 …
# ⚠️  miss [8975254925] 둥우리 속에는 무엇이 잔뜩 들어 있었나요?…
# ⚠️  miss [8975254925] 마르셀리노는 무엇이 들어 있는 상자 위에 몸을…
# ⚠️  miss [8975254925] 마르셀리노에게 뭐라고 말했나요?…
# ⚠️  miss [8975254925] 귀여운 아기는 문지기 수사의 가슴에 안긴 채 …
# ⚠️  miss [8975254925] 마르셀리노는 겨우 구두를 신고 무엇을 했나요?…
# ⚠️  miss [8975254925] 마르셀리노는 언제 자장 할아버지에게 세례 아저…
# ⚠️  miss [8975254925] 마르셀리노는 보물을 어떻게 하였나요?…
# ⚠️  miss [8975254925] 이미 무엇을 지났나요?…
# ⚠️  miss [8975254925] 문득 무엇이 눈에 띄었나요?…
# ⚠️  miss [8975254925] 또 한 마리의 제비가 새집을 메우려고 무엇을 …
# ⚠️  miss [8975254925] 마르셀리노는 무엇을 해도 시간이 넉넉하다고 생…
# ⚠️  miss [8975254925] 어떠한 재산도 자기 것으로 가져서는 안 되는 …
# ⚠️  miss [8975254925] 마카리오는 불같이 화를 내며 무엇을 했나요?…
# ⚠️  miss [8975254925] 문지기 수사는 무엇을 가르쳐 주었나요?…
# ⚠️  miss [8975254925] 마르셀리노는 뭐라고 대답했나요?…
# ⚠️  miss [8975254925] 마르셀리노는 무엇을 손에 들고 있었나요?…
# ⚠️  miss [8975254925] 나귀를 타고 가난한 수도원에 찾아 온 사람은 …
# ⚠️  miss [8975254925] 새로 온 면장의 질문에 수사들은 어떤 대답을 …
# ⚠️  miss [8975254925] 피오 수사는 어떤 행동을 하며 말을 이었나요?…
# ⚠️  miss [8975254925] 수사들이 수리한 집이 어떻게 되었나요?…
# ⚠️  miss [8975255093] 오빠는 무엇을 좋아하지 않나요?…
# ⚠️  miss [8975255093] 료바가 마음에 들지 않는 이유는 그가 어디의 …
# ⚠️  miss [8975255093] 나는 누가  모든 것을 다 알아 버렸다는 걸 …
# ⚠️  miss [8975255093] 료바의 행동이 못마땅하게 느껴지는 이유는 무엇…
# ⚠️  miss [8975255093] 나는 어떤 생각을 했나요?…
# ⚠️  miss [8975255093] 나는 음악가들이 왜 바이올린에 턱을 기대고 눈…
# ⚠️  miss [8975255093] 나는 무슨 시간에 선생님들이 어떻게 새해를 맞…
# ⚠️  miss [8975255093] 아동 앙상블이 있는 곳은 어디인가요?…
# ⚠️  miss [8975255093] 료바가 유명한 음악가가 되지 못한다면 나는 어…
# ⚠️  miss [8975255093] 내가 부탁을 하면 부모님은 어떻게 하셨나요?…
# ⚠️  miss [8975255093] 내가 기하 점수를 4점을 받으면 아빠와 엄마는…
# ⚠️  miss [8975255093] 새해보다 닷새나 전에 여는 새해 축하회라는 말…
# ⚠️  miss [8975255093] 나는 오빠가 음악학교 학생이라는 사실을 누구에…
# ⚠️  miss [8975255093] 엄마는 언제 청소를 말끔히 해 놓으셨나요?…
# ⚠️  miss [8975255093] 일이 어긋나 어디에서 일하는 가수가 오지 못했…
# ⚠️  miss [8975255093] 게시판 한가운데에 새로운 종이쪽지는 무엇에 대…
# ⚠️  miss [8975255093] 외할머니가 마치 어디에서 공부하고 있는 것 같…
# ⚠️  miss [8975255093] 전화를 걸기 위해 어디로 갔나요?…
# ⚠️  miss [8975255093] 전화를 양보하지 않는 나에게 외할머니는 어떻게…
# ⚠️  miss [8975255093] 내가 우러러보는 사람은 누구인가요?…
# ⚠️  miss [8975255093] 나에게 문을 열어준 사람은 누구인가요?…
# ⚠️  miss [8975255093] 어떤 이들이 거의 모두 일기를 쓰고 있었나요?…
# ⚠️  miss [8975255093] 나는 이번 일을 겪으며 무엇을 깨달았나요?…
# ⚠️  miss [8975255093] 나는 언제 리랴의 집 모퉁이에 숨어서 감시했나…
# ⚠️  miss [8975255093] 걱정 없다는 내 말에 그는 어떻게 반응했나요?…
# ⚠️  miss [8975255093] 무대로 나간 나의 얼굴은 어땠을 거로 생각했나…
# ⚠️  miss [8975255093] 휴게 시간이 되기를 기다렸다가 나는 어떻게 했…
# ⚠️  miss [8975255093] 내가 료바의 말을 흘려 들은 이유는 무엇인가요…
# ⚠️  miss [8975255093] 아리나가 무대에 오른 것을 본 나는 어떻게 했…
# ⚠️  miss [8975255093] 제2부의 끄트머리에서 외국 노래의 내용을 소개…
# ⚠️  miss [8975255093] 나는 오빠의 연주회가 있을 때마다 무엇을 할 …
# ⚠️  miss [8975255093] 나는 어디에서 강연을 들었나요?…
# ⚠️  miss [8975255093] 외할머니는 어디가 어두워서 위험하다고 했나요?…
# ⚠️  miss [8975255093] 아리나가 부르는 노래에 나오는 시는 어떻게 들…
# ⚠️  miss [8975255093] 료바는 아리나의 말에 어떤 반응을 보였나요?…
# ⚠️  miss [8975255093] 나는 옷을 다려 입고 어디에 간다고 어머니에게…
# ⚠️  miss [8975255093] 내가 그 사람이 좋다고 생각하는 이유는 무엇인…
# ⚠️  miss [8975255093] 내가 아리나의 다른 쪽 눈을 지금까지 한 번도…
# ⚠️  miss [8975255093] 모두들 무엇에 대해 이야기하고 있나요?…
# ⚠️  miss [8975255093] 그녀는 색소폰을 얼마큼 듣나요?…
# ⚠️  miss [8975255093] 내가 무대로 나가자 무슨 일이 일어났나요?…
# ⚠️  miss [8975255093] 아빠는 시나 노래에 대해 어떻게 생각하나요?…
# ⚠️  miss [8975255093] 여기저기 옮겨 다니는 것은 결코 편한 일은 아…
# ⚠️  miss [8975255093] 아동 앙상블과 총지휘자가 있는 곳은 어디인가요…
# ⚠️  miss [9788967760120] 원숭이가 곰돌이 미술관에 갖고 온 것은 무엇인…
# ⚠️  miss [9788998212759] 부엉이 작가의 이야기는 어떤 내용인가요?…
# ⚠️  miss [9788998212865] 새로운 약속을 정할 때면 멋대로 마을 사람들은…
# ⚠️  miss [9788998212995] 들어오는 문 옆에 작은 기계를 보고 다람은행 …
# ⚠️  miss [9791157595822] 하드로사우루스는 누구의 공격을 피하기 위해 무…
# ⚠️  miss [9791157595839] 볼카노돈을 향해 움직인 것은 누구인가요?…
# ⚠️  miss [9791157595853] 마준가사우루스의 화석은 어느 곳에서 발견되었나…
# ⚠️  miss [9791157595853] 아프리카 마다가스카르섬의 마준가 사막에서 발견…
# ⚠️  miss [9791157595853] 양추아노사우루스는 무엇을 보고 섣불리 달려들었…
# ⚠️  miss [9791157595853] 바리오닉스는 무엇으로 물고기를 찍어 올렸나요?…
# ⚠️  miss [9791157595877] 미크로랍토르들은 알사사우루스를 보고 어떻게 하…
# ⚠️  miss [9791157595877] 암컷보다 수컷의 돌기가 더 큰 이유가 무엇일까…
# ⚠️  miss [9791157595877]  무리의 우두머리는 땅을 박차고 뛰어올라 어떻…
# ⚠️  miss [9791157595877] 딜로포사우루스가 후아양고사우루스를 발견하고 어…
# ⚠️  miss [9791157595884] 사우로르니토이데스가 빠르게 달릴 수 있었던 이…
# ⚠️  miss [9791157595891] 암펠로사우루스의 화석이 발견된 곳은 어디인가요…
# ⚠️  miss [9791157595907] 펠레카니미무스의 턱 주머니는 어떤 일을 할 수…
# ⚠️  miss [9791157595921] 티라노사우루스가 달릴 때 햇빛에 번뜩인 것은 …
# ⚠️  miss [9791157596010] 몬타노케라톱스는 어떤 동물이죠?…
# ⚠️  miss [9791157596010] 엄마 몬타노케라톱스는 놀라서 어떻게 했지?…
# ⚠️  miss [9791157596010] 플라테오사우루스가 코를 킁킁거리며 뭐라고 애기…
# ⚠️  miss [9791157596010] 데이노니쿠스 코레아넨시스들은 사냥에 성공한 후…
# ⚠️  miss [9791157596010] 기가노토사우루스를 꺽기 위해 메가랍토르는 어떻…
# ⚠️  miss [9791157596010] 계속 나뭇잎만 먹은 세그노사우루스는 어땠나요?…
# ⚠️  miss [9791165432997] 독일군이 총을 쏘았지만 마크 전차는 어땠나요?…
# ⚠️  miss [9791165432997] 전차를 싸우는 컴퓨터라는 부르는 것은 무슨 의…
# ⚠️  miss [9791165432997] 우리나라 지형에서 잘 달리며 명중률도 높은 한…
# ⚠️  miss [9791165432997] 드래건 러너는 어느 나라의 군대가 사용하고 있…
# ⚠️  miss [9791165432997] 전차와 생김새는 비슷한 반면 약한 것은 무엇인…
# ⚠️  miss [9791165432997] 군용 트럭 케이 915를 언제 이용할까요?…
# ⚠️  miss [9791165432997] 비행기에서 떨어뜨리는 것은 무엇인가요?…
# ⚠️  miss [9791165432997] 지(G) 바겐이 하는 일을 무엇인가요?…
# ⚠️  miss [9791165432997]  전 세계 60개국이 넘는 나라에서 지 바겐을…
# ⚠️  miss [9791165433017] 스포츠 유틸리티 자동차가 훨씬 힘 있게 달릴 …
# ⚠️  miss [9791165433017] 여행하는 사람들이 늘면서 함께 늘어나고 있는 …
# ⚠️  miss [9791165433017] 피아트 500의 별명이 왜 생쥐가 되었을까요?…
# ⚠️  miss [9791165433017] 우리나라 최초의 택시는 언제 처음 영업을 했나…
# ⚠️  miss [9791165433017] 포르쉐는 나치의 구호인 처음 이름이 싫어서 어…
# ⚠️  miss [9791165433024] 히틀러는 탄 차는 어떤 특징을 가지고 있나요?…
# ⚠️  miss [9791165433024] 자동차에 대한 생각이 같은 찰스 롤스와 프레드…
# ⚠️  miss [9791165433024] 베엠베의 라디에이더의 공기구멍이 우리 몸속의 …
# ⚠️  miss [9791165433024] 볼보를 만든 두 사람은 누구인가요?…
# ⚠️  miss [9791165433024] 볼보 엑스시90 알의 디자인은 어떠하였나요?…
# ⚠️  miss [9791165433024] 차 이름에 팬텀을 붙인 이유가 무엇인가요?…
# ⚠️  miss [9791165433024] 달리가 별장이라고 불리는 것으로 보아 무엇을 …
# ⚠️  miss [9791165433031] 공항 소방차가 다른 소방차와 다른 특징은 무엇…
# ⚠️  miss [9791165433031] 사람들이 쓰러지려고 하는 이유는 무엇인가요?…
# ⚠️  miss [9791165433048] 다카르 랠리는 어느 지역에서 아프리카 세네갈의…
# ⚠️  miss [9791165433062] 탱크로리는 다른 말로 뭐라고 할까요?…
# ⚠️  miss [9791165433062] 건초 압축기는 어떤 일을 하는 기계인가요? …
# ⚠️  miss [9791165433079] 길이나 바닥을 단단하게 하기 위해 돌들을 어떻…
# ⚠️  miss [9791165433079] 트럭믹서는 무엇을 하는 차인가요?…
# ⚠️  miss [9791165437787] 밍크스는 어디로 다가갔나요?…
# ⚠️  miss [9791165437787] 밍크스는 불을 피우고 무엇을 했나요?…
# ⚠️  miss [9791165437787] 밍크스는 여전히 어떻게 보였나요?…
# ⚠️  miss [9791165437787] 마녀는 냄비 속을 휘저으면서 무엇을 했나요?…
# ⚠️  miss [9791165437787] 마녀를 만나고 왜 도망치지 못했나요?…
# ⚠️  miss [9791165437787] 학교 종이 울리자 밍크스는 어떤 반응을 보였나…
# ⚠️  miss [9791165437787]  미니킹은 밝고 깨끗한 다른 집들을 어떻게 바…
# ⚠️  miss [9791165437787] 탐정은 밍크스를 어떻게 쳐다보고 있나요?…
# ⚠️  miss [9791165437787] 집안의 시끄러운 소리에 밍크스는 어떤 행동을 …
# ⚠️  miss [9791165437787] 거실에 나온 할머니의 모습은 어땠나요?…
# ⚠️  miss [9791165437787] 중요한 말을 하려던 프란세스의 마음은 어땠나요…
# ⚠️  miss [9791165437787] 밍크스는 마술 가루를 너무  많이 써버리면 어…
# ⚠️  miss [9791165437787] 어떤 일을 당하는지 두고 봐야겠다는 밍크스의 …
# ⚠️  miss [9791165437787] 여자아이가 웃으며 빗자루를 타고 있을때 누가 …
# ⚠️  miss [9791165437787] 교장 선생님이 가고 아이들은 어떤 행동을 했나…
# ⚠️  miss [9791165437787] 오늘 밤은 아마 잠을 잘 수 없을 것 같다는 …
# ⚠️  miss [9791165437787] 프란세스의 집을 보고 밍크스는 어떤 생각을 했…
# ⚠️  miss [9791165437787] 할머니는 무엇으로 장식된 모자를 쓰고 있나요?…
# ⚠️  miss [9791165437787] 밍크스는 프란세스의 할머니를 생각하자 어떤 기…
# ⚠️  miss [9791165437787] 밍크스는 어디에 도착하자 숨이 찼나요?…
# ⚠️  miss [9791165437787] 아름다운 여인은 고개를 저으며 어떤 행동을 했…
# ⚠️  miss [9791165437787] 교장 선생님은 밍크스를 보고 어떤 행동을 했나…
# ⚠️  miss [9791165437787] 프란세스는 남자에게 무엇이 싫다고 말하나요?…
# ⚠️  miss [9791165437787] 피리 소리에 따라 간 아이들의 아버지와 어머니…
# ⚠️  miss [9791165437787] 마녀는 밍크스에게 어떤 행동을 하고 있나요?…
# ⚠️  miss [9791165437787] 작은 모습을 한 것은 어디에 앉아 있나요?…
# ⚠️  miss [9791165437787] 밍크스는 무엇을 선반에 올려놓았나요?…
# ⚠️  miss [9791165437787] 마녀는 밍크스에게 무엇을 만들어 놓으라고 시켰…
# ⚠️  miss [9791165437787] 손과 얼굴을 씻어고 있는 밍크스는 본 마녀는 …
# ⚠️  miss [9791165437787] 밍크스는 실험을 할 때마다 어떤 기분이 들었나…
# ⚠️  miss [9791165437787] 재판장은 무엇을 치며 말했나요?…
# ⚠️  miss [9791165437787] 피리꾼 아저씨가 일을 끝내고 가려고 하자 밍크…
# ⚠️  miss [9791165437787] 맨 처음 빌리 마틴은 어떻게 물었나요?…
# ⚠️  miss [9791165437787] 밍크스를 바라보는 빌리의 마음은 어떤가요?…
# ⚠️  miss [9791165437787] 봅은 할머니가 자랑스러워서 어떻게 말했나요?…
# ⚠️  miss [9791165437787] 밍크스가 앨리스에게 어떤 말투로 말했나요?…
# ⚠️  miss [9791165437787] 앨리스가 얼른 결정을 못 내리자 모두 어떤 행…
# ⚠️  miss [9791165437787] 밍크스의 말을 듣고 프란세스는 어떤 행동을 했…
# ⚠️  miss [9791165437787] 무서운 엄마에게 들키면 어떻게 될 수도 있다고…
# ⚠️  miss [9791165437787] 스쿠쳐는 센트에게 어떤 행동을 했나요?…
# ⚠️  miss [9791165437787] 이상한 짐승을 보고 밍크스는 어떤 말을 했나요…
# ⚠️  miss [9791165437787] 탐정은 어떤 모습으로 찾아왔나요?…
# ⚠️  miss [9791165437787] 잠이 깬 마녀는 무엇을 했나요?…
# ⚠️  miss [9791165437787] 빨리 가자는 할머니의 명령으로 아이들은 어떤 …
# ⚠️  miss [9791165437794] 팀은 무엇을 기다리고 있나요?…
# ⚠️  miss [9791165437794] 엄마에게 줄 선물로 무엇을 샀나요?…
# ⚠️  miss [9791165437794] 팀은 아빠에게 뭐라고 인사했나요?…
# ⚠️  miss [9791165437794] 팀은 숲속에서 무엇을 만날지도 모른다고 했나요…
# ⚠️  miss [9791165437794] 훌륭한 선물을 받은 팀의 기분은 어떤가요?…
# ⚠️  miss [9791165437794] 아빠와 팀은 무엇을 만들었나요?…
# ⚠️  miss [9791165437794] 팀이 일부러 물웅덩이 속으로 첨벙첨벙 걸은 이…
# ⚠️  miss [9791165437794] 팀은 물에 빠진 쥐처럼 어떻게 됐나요?…
# ⚠️  miss [9791165437794] 자신감이 든 검정 양은 누가 놀려도 뭐라고 말…
# ⚠️  miss [9791165437794] 팀은 뭐라고 소리쳤나요?…
# ⚠️  miss [9791165437794] 팀은 학교에 가기 전에 왜 시장으로 나갔나요?…
# ⚠️  miss [9791165437794] 신사라고 하는 건 정말 고된 거라며 어떤 게 …
# ⚠️  miss [9791165437794] 팀의 기분은 어땠나요?…
# ⚠️  miss [9791165437794] 팀이라는 이름 말고 다른 어떤 이름을 생각했나…
# ⚠️  miss [9791165437794] 팀은 물웅덩이와 비를 어떻게 했나요?…
# ⚠️  miss [9791165437794] 팀이 귀를 기울인 이유는 무엇인가요?…
# ⚠️  miss [9791165437794] 왜 아주 좋은 아이라고 말했을까요?…
# ⚠️  miss [9791165437794] 팀이 모자를 벗기 싫었던 이유는 여전히 어떤 …
# ⚠️  miss [9791165437794] 도둑이 된 바람샌들은 어떤 목소리로 외쳤나요?…
# ⚠️  miss [9791165437794] 조리대 옆 벽에 붙어 있는 건 무엇인가요?…
# ⚠️  miss [9791165437794] 세 식구는 무엇을 하면서 오랫동안 이야기를 했…
# ⚠️  miss [9791165437794] 아빠가 일을 할 필요가 없어진 이유는 무엇인가…
# ⚠️  miss [9791165437817] 더글러스 씨는 누가 틀림없이 살아 있다고 생각…
# ⚠️  miss [9791165437817] 키비는 주변을 살피기 위해 어떻게 했나요?…
# ⚠️  miss [9791165437817] 론지는 누가 자신을 도와줄 거라고 했나요?…
# ⚠️  miss [9791165437817] 메저가 한 말이 어느 면에서는 사실인 이유는 …
# ⚠️  miss [9791165437817] 새끼 코끼리들이 키비에게 온 이유는 무엇인가요…
# ⚠️  miss [9791165437817] 키비는 어디를 헤엄쳐 건너기 시작했나요?…
# ⚠️  miss [9791165437817] 알리바마의 말에 누가 맞장구를 쳤나요?…
# ⚠️  miss [9791165437817] 치타 켈소는 어디에서 기다리고 있나요?…
# ⚠️  miss [9791165437817] 메저를 잡은 것은 누구인가요?…
# ⚠️  miss [9791165437817] 마크는 키비를 어떻게 도왔나요?…
# ⚠️  miss [9791165437817] 키비는 어디까지 자주 나갔나요?…
# ⚠️  miss [9791165437817] 메저는 바나나를 먹듯 쉽게 진흙을 밟고 어디를…
# ⚠️  miss [9791165437817] 조의 기분을 좋게 하려면 키비가 사저에게 어떻…
# ⚠️  miss [9791165437817] 키비는 코끼리에게 어떻게 하며 말했나요?…
# ⚠️  miss [9791165437817] 작은 시냇가에는 무엇이 자라고 있었나요?…
# ⚠️  miss [9791165437817] 키비를 위해 특별 디저트로 무엇을 먹자고 했나…
# ⚠️  miss [9791165437817] 키비가 어디로 냅다 뛰었나요?…
# ⚠️  miss [9791165437817] 아이가 좀 더 살이 찔 때까지 기다리자고 한 …
# ⚠️  miss [9791165437817] 멋쟁이 짐은 키비를 태우고 밀림 속 어디까지 …
# ⚠️  miss [9791165437817] 키비는 얼룩말 등에 올라타고 무엇을 알려주었나…
# ⚠️  miss [9791165437817] 재미있게 하려고 붙였다는 말은 누가 했나요?…
# ⚠️  miss [9791165437817] 로튼은 어떻게 눈을 떴나요?…
# ⚠️  miss [9791165437817] 샐리는 원숭이들과 무엇을 하고 있었나요?…
# ⚠️  miss [9791165437824] 자전거를 멈춘 시레는 어떤 모습으로 말했나요?…
# ⚠️  miss [9791165437824] 홀름 씨는 전화를 걸고 어디로 나갔나요?…
# ⚠️  miss [9791165437824] 홀름 씨가 나가고 토파는 무엇을 하였나요?…
# ⚠️  miss [9791165437824] 화를 내는 모습을 본 토파의 엄마는 어떤 반응…
# ⚠️  miss [9791165437824] 잠이 든 모습을 확인 한 사람은 그 다음 어떤…
# ⚠️  miss [9791165437824] 외마디 소리는 어디서 들렸나요?…
# ⚠️  miss [9791165437824] 수상한 사람은 방바닥의 구멍에서 거꾸로 떨어졌…
# ⚠️  miss [9791165437824] 토파는 오토를 어떻게 저울 위로 올리자고 했나…
# ⚠️  miss [9791165437824] 라이안 씨가 문에 귀를 대고 들으니 무슨 소리…
# ⚠️  miss [9791165437824] 라이안 씨는 수화기를 놓으며 뭐라고 중얼거렸나…
# ⚠️  miss [9791165437824] 플로라 부인 방바닥에는 누가 있었나요?…
# ⚠️  miss [9791165437824] 사이렌 소리가 요란스레 울려퍼지자 사람들은 어…
# ⚠️  miss [9791165437824] 플로라 부인은 홀름 씨에게 뭐라고 물어봤나요?…
# ⚠️  miss [9791165437824] 플로라 부인은 홀름 씨의 이야기를 듣기 위해 …
# ⚠️  miss [9791165437824] 홀름 씨는 어떤 음료를 마시나요?…
# ⚠️  miss [9791165437824] 홀름 씨가 대답하자 서장은 호주머니에서 무엇을…
# ⚠️  miss [9791165437824] 선생님의 받아쓰기 공부를 시작하자는 제안에 아…
# ⚠️  miss [9791165437824] 토파는 어떻게 중얼거렸나요?…
# ⚠️  miss [9791165437824] 빵 가게 아주머니는 포르마 씨에게 무슨 부탁을…
# ⚠️  miss [9791165437824] 카페 안에 자리가 넘쳐 어린 꼬마들은 어떤 모…
# ⚠️  miss [9791165437824] 어떻게 유모차가 꽃밭에 들어왔나요?…
# ⚠️  miss [9791165437824] 라이안 씨가 묻자 누구의 소리가 났나요?…
# ⚠️  miss [9791165437824] 지친 다리로 계단을 올라가니 무슨 일이 일어나…
# ⚠️  miss [9791165437824] 토파는 어디를 가리키며 말했나요?…
# ⚠️  miss [9791165437824] 비고는 생선시장에 어떻게 갔나요?…
# ⚠️  miss [9791165437824] 오토는 어떤 코뿔소인가요?…
# ⚠️  miss [9791165437824] 왜 코뿔소 오토는 빵 열개가 모자란다고 할까요…
# ⚠️  miss [9791165437824] 숨이 찬 비고의 모습을 보고 토파 엄마는 어떻…
# ⚠️  miss [9791165437824] 비고는 무엇을 말했나요?…
# ⚠️  miss [9791165437824] 검은 그림자 불구경을 하기 위해 어떤 모습이 …
# ⚠️  miss [9791165437824] 소방대원은 말하고 나서 무엇을 했나요?…
# ⚠️  miss [9791165437824] 뱃고동 소리가 울려 퍼지자 선원들은 어떻게 했…
# ⚠️  miss [9791165437824] 검은 빵을 다 먹은 뒤 화초 잎사귀를 먹는 코…
# ⚠️  miss [9791165437824] 토파는 무엇을 하기 시작했나요?…
# ⚠️  miss [9791165437824] 비고는 뭐라고 토파에게 물었나요?…
# ⚠️  miss [9791165437824] 토파가 말하면서 쓱쓱 그려 나간 그림은 어떤 …
# ⚠️  miss [9791165437831] 집이 기우뚱하고 흔들리더니 어떻게 됐을까요?…
# ⚠️  miss [9791165437831] 갈 거라고 말할 때 감정은 어땠을까요?…
# ⚠️  miss [9791165437831] 요술 할멈은 지지 않고 어떻게 했을까요?…
# ⚠️  miss [9791165437831] 임금님은 깜짝 놀라 어떤 행동을 했을까요?…
# ⚠️  miss [9791165437831] 로버트는 선장에게 부탁해서 어떤 일이 생겼을까…
# ⚠️  miss [9791165437831] 행렬 한가운데는 무엇이 있었을까요?…
# ⚠️  miss [9791165437831] 신하들은 임금님이 노여워하고 있는 것을 알아채…
# ⚠️  miss [9791165437831] 세 사람은 기관차 추장에게 칸막이에 관해 설명…
# ⚠️  miss [9791165437831] 세 사람은 자물쇠로 문을 잠그고 어떤 행동을 …
# ...
# ⚠️  miss [9788968730733] 5월 15일은 무슨 날일까요?…
# ⚠️  miss [9788968730733] 하얀 눈이 펑펑 내리면 친구들과 무엇을 할까요…
# ⚠️  miss [9788968730788] 코코의 도시락을 찾기 위해 아기 동물들은 어떻…
# ⚠️  miss [9788968730825] 제이미는 엄마 말을 듣고 어땠나요?…
# ⚠️  miss [9788968730849] 개는 집에 도둑이 든 걸 어떻게 알아채나요?…
# ⚠️  miss [9788968731006] 미오는 왜 엄마를 찾았나요?…
# ⚠️  miss [9788968731099] 집으로 돌아가는 길에 현아는 어떤 모습을 보여…
# ⚠️  miss [9788968731129] 장기 자랑 대회가 열리는 곳은 어디인가요?…
# ⚠️  miss [9788993828030] 단단한 등딱지를 가진 동물은 누구인가요?…
# ⚠️  miss [9788993828030] 토끼처럼 어떤 행동을 할 수 있을까요?…
# ⚠️  miss [9788993828115] 누구의 방귀 냄새인지 궁금해서 어떻게 할까요?…
# ⚠️  miss [9788993828306] 나는 아빠에 대해 어떻게 생각하나요?…
# ⚠️  miss [9788927206521] 누가 식물원으로 현장 수업을 가나요?…
# ⚠️  miss [9788927206521] 선생님이 아이들을 데리러 와서 뭐라고 말씀하셨…
# ⚠️  miss [9788927206521] 초록 불이 켜지면 횡단보도를 건널 때 무엇을 …
# ⚠️  miss [9788927206576] 자전거 전용 도로 표지판을 언제 봤나요?…
# ⚠️  miss [9788927206781] 미끄럼틀을 어떤 식으로 타면 다칠 수 있을까요…
# ⚠️  miss [9788927206965] 같이 가자는 아저씨에게 현철이는 뭐라고 말했나…
# ⚠️  miss [9788927206965] 엄마의 말에 현철이는 기분이 어땠나요?…
# ⚠️  miss [9788927206972] 아주머니는 미나를 어떻게 도와주었나요?…
# ⚠️  miss [9788927206972] 미나는 아저씨의 손을 뿌리치고 어떻게 행동했나…
# ⚠️  miss [9788927207085] 선생님은 희선이의 눈에 들어간 먼지를 씻겨주기…
# ⚠️  miss [9788927207092] 어떻게 해서 코피가 더 이상 안 났나요?…
# ⚠️  miss [9788927207108] 지수는 무엇을 다짐했나요?…
# ⚠️  miss [9788963835129] 대원이는 누구와 함께 방귀를 줄이는 방법을 생…
# ⚠️  miss [9788963835129] 대원이 눈에 이쁜 아이는 누구인가요?…
# ⚠️  miss [9788963835129] 대원이를 누가 위로 해주었나요?…
# ⚠️  miss [9788963835129] 방귀 냄새가 고약하자 대원이는 아빠에게 뭐라고…
# ⚠️  miss [9788963835822] 무엇을 탈 때 지켜야 할 약속에 대해 이야기하…
# ⚠️  miss [9788963835822] 불이 난 걸 보면 어떻게 해야 하나요?…
# ⚠️  miss [9788963835990] 놀이터에는 누가 있었나요?…
# ⚠️  miss [9791185721293] 아빠가 사 온 무섭게 생긴 가면으로 어떻게 하…
# ⚠️  miss [9791185721309] 무슨 잔치가 열렸나요?…
# ⚠️  miss [9791185721378] 모래바람이 불어오자 젠마는 모래바람을 피하려고…
# ⚠️  miss [9791185721415] 아빠와 함께 찍은 사진이나 동영상을 홈페이지에…
# ⚠️  miss [9791185721484] 개미는 벌을 받는다고 생각하며 후회했지만 어떻…
# ⚠️  miss [9791185721545] 작은 물고기들은 순식간에 한데 모여 무엇을 하…
# ⚠️  miss [9791185721545] 작은 물고기들의 용기는 어떻게 생겼나요?…
# ⚠️  miss [9791185721590] 다음 수업 시간은 무엇인가요?…
# ⚠️  miss [9791185721590] 다음은 무슨 시간인가요?…
# ⚠️  miss [9791185721590] 탁탁이와 송송이가 다투고 있을 때 선생님은 어…
# ⚠️  miss [9791185721668] 마을에 일어난 이상한 일들이 모두 무엇 때문일…
# ⚠️  miss [9791185721682] 친구들은 무엇이 무시무시하다고 했나요?…
# ⚠️  miss [9791185721682] 맘보가 나무의 부탁을 들어주자 어떻게 되었나요…
# ⚠️  miss [9791185721712] 다람쥐 세 마리는 어디에 살고 있었나요?…
# ⚠️  miss [9791186298763] 하늘이는 다래를 보고 장난스럽게 뭐라고 말했어…
# ⚠️  miss [9791186298763] 반딧불이 애벌레를 잡은 다래는 어떤 행동을 했…
# ⚠️  miss [9791186298763] 무엇을 보고 있나요?…
# ⚠️  miss [9791186298770] 왜 갓 구운 빵을 사러 가나요?…
# ⚠️  miss [9791186298787] 고리던지기 하여 얼마나 넣었나요?…
# ⚠️  miss [9791186298787] 더러운 손으로 귀지를 어떻게 하면 안 될까요?…
# ⚠️  miss [9791186298787] 펭뽀가 이어폰을 끼어서 어떻게 되었나요?…
# ⚠️  miss [9791186298794] 뇌가 기억하고 있다가 바나나를 보기만 해도 어…
# ⚠️  miss [9791186298794] 누가 연극을 하나요?…
# ⚠️  miss [9791186298794] 누가 아침을 이 닦기로 시작하나요?…
# ⚠️  miss [9791186298800] 우주의 알쏭달쏭 별에서 최고의 먹보는 누구와 …
# ⚠️  miss [9791186298831] 추우면 입모근이 어떻게 되나요?…
# ⚠️  miss [9791186298848] 난소는 언제 아기씨를 내보내나요?…
# ⚠️  miss [9791186298848] 아기들 앞모습을 보면 어떨까요?…
# ⚠️  miss [9791186298848] 마이아는 왜 고개를 빼고 연두와 자기의 배를 …
# ⚠️  miss [9791186298848] 배꼽이 없는 동물은 어떤 동물인가요?…
# ⚠️  miss [9791186298855] 남자와 여자의 겉모습은 어떻게 다른가요?…
# ⚠️  miss [9791186298855] 폐가 하는 일은 무엇일까요?…
# ✅ train.json — books:1441  no-sub:1
# VAL:   0%|          | 0/284 [00:00<?, ?it/s]
# ⚠️  miss [9791128216954] 빗방울이 창문을 두드린 이유는 무엇인가요?…
# ⚠️  miss [9791159424700] 이상한 일은 어디에서 일어났나요?…
# ⚠️  miss [9791159425110] 호랑이와 도둑은 꽉 붙어서 무엇을 했나요?…
# ⚠️  miss [9791165432423] 친구와 함께 그네를 탔을 때 어떤 기분을 느낄…
# ⚠️  miss [9791165434724] 아이의 배변을 도와주려고 하는 이는 누구인가요…
# ⚠️  miss [9791165434724] 손을 닦은 아이가 야옹이에게 뭐라고 말했나요?…
# ⚠️  miss [9791165435950] 책은 혼자 보는 것보다 어떻게 보는 것이 더 …
# ⚠️  miss [9791165436025] 엄마 배에 손을 대어 본 토리는 아기가 뭘 한…
# ⚠️  miss [9791165954277] 어떤 꿈을 꾸나요?…
# ⚠️  miss [9791165954277] 누가 아기를 지켜주나요?…
# ⚠️  miss [9788954337762] 늑대는 모자에 무엇을 했나요?…
# ⚠️  miss [9788997300877] 어디서 양들을 불렀나요?…
# ⚠️  miss [9791165432591] 까만 고양이가 어디로  뛰어들었을까요?…
# ⚠️  miss [9791165432591] 초콜릿을 너무 열심히 떠먹다가 어떻게 됐을까요…
# ⚠️  miss [9791165434083] 유미가 뭐라고 말했나요?…
# ⚠️  miss [9791165950071] 엉덩이에 무엇이 있으면 좋겠다고 생각했나요?…
# ⚠️  miss [9791165950224] 조각구름은 어디로 들어가 애벌레를 태우고 왔을…
# ⚠️  miss [9791165950323] 엄마에게 가기 위해 팝콘과 함께 어떤 행동을 …
# ⚠️  miss [9791190861977] 솜사탕처럼 녹은 음식은 무엇인가요?…
# ⚠️  miss [9791190861984] 조이와 엘리는 누구와 함께 꼬마 산타가 되었나…
# ⚠️  miss [8975253554] 물이 굉장히 차가웠지만 신기한 돌을 가져오기 …
# ⚠️  miss [8975253554] 고슴도치 라테와 다람쥐 츄움은 다리를 다 건너…
# ⚠️  miss [8975253554] 신비한 돌이 있는 곳은 어디인가요?…
# ⚠️  miss [8975253554] 츄움은 눈을 휘둥그렇게 뜨고 뭐라고 말했나요?…
# ⚠️  miss [8975253554] 임금은 하품을 하더니 어떻게 하였나요?…
# ⚠️  miss [8975253554] 라테에게 달려 온 곰 세 마리는 어떻게 하였나…
# ⚠️  miss [8975253554] 신기한 돌을 다시 배낭에 넣은 고슴도치와 다람…
# ⚠️  miss [8975253554] 밖에서 나는 요란한 소리는 어떤 소리였나요?…
# ⚠️  miss [8975253554] 물이 나오는 신기한 돌을 가져가지 못하면 뭐라…
# ⚠️  miss [8975253554] 문을 활짝 연 것은 누구인가요?…
# ⚠️  miss [8975253554] 문을 열겠다고 한 것은 누구인가요?…
# ⚠️  miss [8975253554] 아무도 보지 않는 틈을 타서 주스 잔을 듣고 …
# ⚠️  miss [8975253554] 광장의 큰 바위문 옆에서 꾸벅꾸벅 졸고 있는 …
# ⚠️  miss [8975253554] 깜짝 놀라 정신이 오락가락하는 것은 누구인가요…
# ⚠️  miss [8975253554] 고슴도치와 다람쥐가 가까스로 광장 큰 문 앞에…
# ⚠️  miss [8975253554] 넓은 방으로 들어간 라테는 무엇을 보았나요?…
# ⚠️  miss [8975253554] 개울물이 흐르고 있는 곳은 어디인가요?…
# ⚠️  miss [8975253554] 소리내어 흐르는 물줄기를 따라 자꾸만 올라가 …
# ⚠️  miss [8975253554] 큰 살쾡이 세 마리가 앞으로 튀어나온 건 언제…
# ⚠️  miss [8975253554] 커다란 매는 쏜살같이 내려와서 어떻게 하였나요…
# ⚠️  miss [8975253554] 숲 가까이 왔을 때 매는 무엇을 보았나요?…
# ⚠️  miss [8975253554] 고슴도치와 다람쥐를 발견하지는 못한 곰은 어떻…
# ⚠️  miss [8975253554] 북으로 계속 가면 어디에 닿게 되나요?…
# ⚠️  miss [8975253554] 이를 드러내고 연설을 시작한 것은 누구인가요?…
# ⚠️  miss [8975253554] 광장이 온갖 곰으로 꽉 차자 나타난 것은 누구…
# ⚠️  miss [8975253554] 내가 하는 말을 늑대가 알아들었던 이유는 무엇…
# ⚠️  miss [8975253554] 이야기가 끝난 건지 물은 건 누구인가요?…
# ⚠️  miss [8975253554] 어쩔 수 없는 일이라고 생각한 것은 무엇인가요…
# ⚠️  miss [8975253554] 광장 저쪽에서 슬그머니 나타난 건 누구인가요?…
# ⚠️  miss [8975253554] 라테를 감옥 안에 밀어 넣은 건 누구인가요?…
# ⚠️  miss [8975253554] 무서운 소리로 울부짖은 것은 누구인가요?…
# ⚠️  miss [8975253554] 그들이 다리를 반쯤 건넜을 때 저쪽에서는 어떤…
# ⚠️  miss [8975253554] 성이 나서 펄펄 뛰고 있는 건 누구일까요?…
# ⚠️  miss [9788960162365] 아기 소나무가 나무들을 걱정하자 아빠 소나무는…
# ⚠️  miss [9788993828733] 독화살 개구리의 피부에는 어떤 독이 있을까요?…
# ⚠️  miss [9788994730233] 우선 무엇을 하기로 했나요?…
# ⚠️  miss [9788994730233] 신하들은 임금님의 머리둘레를 알기 위해서 어떻…
# ⚠️  miss [9788994730233] 거인 대장장이는 어떻게 했나요?…
# ⚠️  miss [9788994730516] 모자를 어떻게 꾸몄나요?…
# ⚠️  miss [9791165951351] 사람들은 왜 늑대를 모두 쫓아 버렸을까요?…
# ⚠️  miss [9788966922802] 꼬마 도깨비가 어디에 있는지 물었더니 친구들은…
# ⚠️  miss [9788966922802] 쌍둥이 형제는 어디에 살고 있을 것 같나요?…
# ⚠️  miss [9788966922802] 아기 원숭이는 나무에 매달린 엄마 원숭이를 어…
# ⚠️  miss [9788966922802] 지도를 다시 만들려면 어떻게 해야 할까요?…
# ⚠️  miss [9788966922802] 집에 불이 왜 켜졌을까요?…
# ⚠️  miss [9788966922802] 깡통 로봇은 어디에 있을까요?…
# ⚠️  miss [9788966922802] 어디에서 장난감을 찾아볼까요?…
# ⚠️  miss [9788966923694] 빨리 크기 위해서 무엇을 해야 할까요?…
# ⚠️  miss [9791157026111] 박사님은 초청장을 어디서 찾아냈나요?…
# ⚠️  miss [9791157026197] 몽몽이의 말을 들은 삼총사는 어떻게 했나요?…
# ⚠️  miss [9791157026203] 삼총사는 연구소가 동네에서 에어컨이 가장 시원…
# ⚠️  miss [9791157026302] 투덜이가 온 힘을 다해 밀며 기합을 넣자 어떻…
# ⚠️  miss [9791157026302] 제일 힘이 센 6학년 형이 있는 힘껏 돌을 밀…
# ⚠️  miss [9791157026326] 박사님이 몽몽이의 엉덩이를 쿡 찌르자 몽몽이는…
# ⚠️  miss [9791165435103] 엄마는 무엇을 하고 있나요?…
# ⚠️  miss [9791165435103] 빛에 반응하기 시작하게 된 이유는 무엇일까요?…
# ⚠️  miss [9791165435127] 오늘은 무슨 날인가요?…
# ⚠️  miss [9791165435127] 맛있는 음식을 먹기 전에 뭐라고 인사했나요?…
# ⚠️  miss [9791165435127] 할머니는 생일인 민이에게 어떤 마음을 전했나요…
# ⚠️  miss [9791165435356] 곰곰이 심사 위원은 어떻게 행동했나요?…
# ⚠️  miss [9791165435578] 무엇이 모두 없어져라고 주문 했나요?…
# ⚠️  miss [9791165435585] 팥 경단과 꿀 경단의 수가 하나씩 모자란 상황…
# ⚠️  miss [9791165435691] 무엇을 하기 전에 그래프의 모양만 보고도 한눈…
# ⚠️  miss [9791165435691] 어떤 이름이 좋겠다고 생각했나요?…
# ⚠️  miss [9791165437428] 비눗방울에 비친 것은 누구와 누구일까요?…
# ⚠️  miss [9791165958343] 날름 고양이에게 몇 마리를 먹어보라고 했을까요…
# ⚠️  miss [9791165958343] 곰은 물고기를 몇마리 잡았을까요?…
# ⚠️  miss [9791188491247] 봄봄이와 밤밤이는 어디로 갔나요?…
# ⚠️  miss [9791190861199] 얼룩말이 공격당하지 않는 이유는 무엇인가요?…
# ⚠️  miss [9791190861199] 얼룩말은 사자를 만나면 어떻게 하나요?…
# ⚠️  miss [9791190861250] 우리는 무지 똑똑해서 무엇을 할 수 있나요?…
# ⚠️  miss [9791190861250] 얼굴이 빨개진 이유는 무엇일까요?…
# ⚠️  miss [9791190861250] 이 나무에서 저 나무로 빠르게 무엇을 할 수 …
# ⚠️  miss [9791190861250] 대부분의 원숭이가 나뭇가지나 물건 등을 잘 잡…
# ⚠️  miss [9791190861304] 나는 흰동가리에게 어떤 생각이 들었나요?…
# ⚠️  miss [9791190861304] 녀석들을 보자 말미잘은 무슨 생각을 했나요?…
# ⚠️  miss [9791190861403] 모래로 목욕을 할 때 어떤 기분일까요?…
# ⚠️  miss [9791190861403] 붉은 볏을 보면 느낌이 어떨까요?…
# ⚠️  miss [9791190861434] 결국 어떻게 되었나요?…
# ⚠️  miss [9791190861434] 어떻게 등 뒤를 보나요?…
# ⚠️  miss [9791190861526] 멀리까지 볼 수 있어 무엇을 잘 하나요?…
# ⚠️  miss [9791190861526] 나를 어떻게 하기가 힘들다고 했나요?…
# ⚠️  miss [9791190861526] 내 몸집만 한 무엇을 잡았나요?…
# ⚠️  miss [9791190861618] 감자와 다르게 고구마는 무엇이 통통해져서 우리…
# ⚠️  miss [9791190861625] 토마토를 키울 때 잊지 말아야 하는 것은 무엇…
# ⚠️  miss [9791190861625] 본잎은 쑥쑥 자라서 어떻게 되었을까요?…
# ⚠️  miss [9791190861625] 흐물흐물 노란 씨를 어떻게 했나요?…
# ⚠️  miss [9791190861694] 새들이 선인장에 집을 짓는 이유는 무엇일까요?…
# ⚠️  miss [9791190861700] 끈끈이주걱을 보면 어떻게 느낄까요?…
# ⚠️  miss [9791128211539] 물방울들은 어디에 사나요?…
# ⚠️  miss [9791165433055] 페라리를 만든 사람은 누구인가요?…
# ⚠️  miss [9791165433055] 람보르기니는 길에서 어떻게 달리나요?…
# ⚠️  miss [9791165433055] 부가티를 예술 작품처럼 만들기 위해 어떻게 하…
# ⚠️  miss [9791165433055] 람보르기니 디아블로라는 이름이 붙여진 이유는 …
# ⚠️  miss [9791165433055] 엔진을 금으로 얇게 씌운 이유는 무엇인가요?…
# ⚠️  miss [9791165433086] 지뢰 방호 장갑차는 영어 이름의 첫 글자를 따…
# ⚠️  miss [9791188491698] 티라노사우루스는 아무리 커다란 공룡도 쓰러뜨릴…
# ⚠️  miss [9791188491698] 마이아사우라는 어떤 어미 도마뱀이라는 뜻인가요…
# ⚠️  miss [9791188491780] 네오바나토르가 뛰어다닌 곳은 어디일까요?…
# ⚠️  miss [9791188491780] 바위 사이를 뒤지는 딜롱 두 마리를 봤을 때 …
# ⚠️  miss [9788960164833] 불개는 뜨거운 해를 어떻게 했나요?…
# ⚠️  miss [9788963830995] 악어가 자꾸 목이 말랐던 이유는 무엇인가요?…
# ⚠️  miss [9788963830995] 병균이는 어떤 친구들을 가장 싫어하나요?…
# ⚠️  miss [9791157594542] 내 맘에 쏙 들은 것을 본 다롱이는 어떻게 행…
# ⚠️  miss [9791165954673] 외계인 쪽쪽이는 손가락을 달라고 하면서 뭐라고…
# ⚠️  miss [9791165954680] 먼지 벌레가 모두 사라져서 기분이 어떨까요?…
# ⚠️  miss [9791165954741] 주호는 사탕을 선물 받고 어떤 생각을 하며 바…
# ⚠️  miss [9791165954758] 과자를 보고 다비는 어떤 기분이였나요?…
# ⚠️  miss [9791165954758] 심술 나무가 작아져서 어떻게 됐을까요?…
# ⚠️  miss [9791165954772] 산신령에게 금이빨을 받은 은토끼는 기분이 어떠…
# ⚠️  miss [9791165954772] 이빨이 어떻게 됐나요?…
# ⚠️  miss [9791165954772] 금토끼는 또 어떻게 말했나요?…
# ⚠️  miss [9791165954857] 삐삐는 연못에서 어떤 행동을 했나요?…
# ⚠️  miss [9791165955083] 버리다는 왜 냠냠 버튼을 눌러 맛있는 간식을 …
# ⚠️  miss [9788961910347] 잿빛 늑대가 나타나서 무슨 행동을 했나요?…
# ⚠️  miss [9788961910347] 니네테는 누구를 좋아하고 있었나요?…
# ⚠️  miss [9788961910347] 워브는 어디로 줄달음질쳤나요?…
# ⚠️  miss [9788961910347] 쫓겨서 도망친 것은 누구일까요?…
# ⚠️  miss [9788961910347] 회색곰이 걸어오는 것을 본 워브는 어디로 올라…
# ⚠️  miss [9788961910347] 통나무집 한 채는 어디에 세워져 있었나요?…
# ⚠️  miss [9788961910347] 휘파람 소리에 놀란 워브는 어떻게 행동했나요?…
# ⚠️  miss [9788961910347] 위니펙의 늑대를 구경한 날은 언제인가요?…
# ⚠️  miss [9788961910347] 워브는 다리를 절며 황폐한 포플러 숲에서 무엇…
# ⚠️  miss [9788961910347] 워브는 날이 갈수록  쇠약해 어떤 상태가 되었…
# ⚠️  miss [9788961910347] 5일째 되는 날 말떼는 어디 근처까지 돌아와 …
# ⚠️  miss [9788961910347] 온천 호텔은 어떤 곳인가요?…
# ⚠️  miss [9788961910347] 강 하류는 어떤 곳이었나요?…
# ⚠️  miss [9788961910347] 두 사람은 사건 현장에서 그리 멀지 않은 곳에…
# ⚠️  miss [9788961910347] 승냥이들이 달려들자 워브는 어떻게 행동했나요?…
# ⚠️  miss [9788961910347] 워브는 어떻게 말을 쓰러뜨렸을까요?…
# ⚠️  miss [9788961910347] 워브는 바위로 무엇을 하며 즐거워 했나요?…
# ⚠️  miss [9788961910347] 곰은 자기 영토 안에서 모습을 감출 때는 언제…
# ⚠️  miss [9788961910347] 어미 곰이 나무나 바위를 놓칠지도 모른다는 걱…
# ⚠️  miss [9788961910347] 회색곰 워브는 어디에서 태어났나요?…
# ⚠️  miss [9788961910347] 레인저는 사냥 목표물을 놓쳤을 때 어떤 행동을…
# ⚠️  miss [9788961910347] 어디에서 여우가 울부짖는 소리가 들려왔나요?…
# ⚠️  miss [9788961910347] 워브는 시체 냄새가 나는 골짜기에 들어가서 어…
# ⚠️  miss [9788961910347] 개들이 덤벼들기를 기다리다 못한 늑대는 어떻게…
# ⚠️  miss [9788961910347] 어떤 개들이 먼저 쓰러져 죽었나요?…
# ⚠️  miss [9788961910347] 개들은 누구의 지시를 받아 늑대에게 덤벼들었나…
# ⚠️  miss [9788961910347] 워브가 먹이를 찾으려고 돌아다닌 곳은 어디일까…
# ⚠️  miss [9788961910347] 밤이 되면 워브는 어디에서 잠을 잤나요?…
# ⚠️  miss [9788961910347] 나는 어디에서 휴식을 취했나요?…
# ⚠️  miss [9788961910347] 워브는 왜 봄이되면 소와 사슴들이 살고 있는 …
# ⚠️  miss [9788961910347] 사슬 때문에 개에게 매번 지는 늑대는 이를 악…
# ⚠️  miss [9788961910347] 늑대와 개의 싸움을 보는 술집 손님들은 어떻게…
# ⚠️  miss [9788961910347] 폴이 팔아버린 새끼늑대는 사슬에 목이 매어진 …
# ⚠️  miss [9788961910347] 새끼 여우는 밤만 되면 무슨 행동을 했나요?…
# ⚠️  miss [9788961910347] 언젠가부터 남의 먹이를 빼앗아 모두 먹어치우기…
# ⚠️  miss [9788961910347] 큰아버지는 말리는 나에게는 어'떻게 했나요?…
# ⚠️  miss [9788961910347] 하인이 삽으로 새끼 여우를 때려죽이려 하자 큰…
# ⚠️  miss [9788961910347] 1881년에 형의 농장에 머물게 된 시턴은 무…
# ⚠️  miss [9788961910347] 회색 곰의 털은 어떤 변화가 있나요?…
# ⚠️  miss [9788961910347] 새로운 것을 가르쳐주겠다고 말한 어미 곰은 어…
# ⚠️  miss [9788961910347] 죽음의 골짜기를 보면 어떤 느낌을 가졌을까요?…
# ⚠️  miss [9788961910347] 쓰러진 어미 곰을 보고 남은 3마리의 새끼 곰…
# ⚠️  miss [9788961910347] 시턴은 동물에게 어떤 마음이었나요?…
# ⚠️  miss [9788961910347] 시턴동물기는 어떤 이야기인가요?…
# ⚠️  miss [9788961910347] 새끼 여우들은 어떻게 생겼나요?…
# ⚠️  miss [9788961910439] 군대를 이끌고 로마로 진격한 카이사르는 어두워…
# ⚠️  miss [9788961910439] 카이사르는 피리 소리를 듣고 어디를 건너갔나요…
# ⚠️  miss [9788961910439] 세상을 구하는 영웅들의 이야기는 우리에게 어떤…
# ⚠️  miss [9788961910439] 카이사르 군대를 당해 낼 수 없었던 게르만인들…
# ⚠️  miss [9788961910439] 어느 민족보다도 용감하고 강력하게 저항했던 민…
# ⚠️  miss [9788961910439] 잠시도 쉬지 않고 달렸던 페이디피데스는 시민들…
# ⚠️  miss [9788961910439] 게르만족을 무찌른 카이사르는 갈리아 지방의 로…
# ⚠️  miss [9788961910439] 카이사르가 제일 먼저 정복한 민족은 누구일까요…
# ⚠️  miss [9788961910439] 알렉산더가 부케팔루스를 타고 있을 때, 독수리…
# ⚠️  miss [9788961910439] 왕자는 말에게 주인이 되어 주겠다고 말하며 어…
# ⚠️  miss [9788961910439] 카이사르는 로마의 제1인자가 될 야심을 품고 …
# ⚠️  miss [9788961910439] 한니발은 부하들에게 최선을 다해 싸울 것을 호…
# ⚠️  miss [9788961910439] 한니발이 가리킨 이탈리아의 기름진 평야를 굽이…
# ⚠️  miss [9788961910439] 이틀 동안 휴식을 취하고 알프스 산을 내려가기…
# ⚠️  miss [9788961910439] 데모스테네스가 느낀 필리포스 왕의 성격은 어떠…
# ⚠️  miss [9788961910439] 카이사르가 로마 지원군과 함께 프톨레마이오스와…
# ⚠️  miss [9788961910439] 알렉산더는 군사들을 이끌고 어디까지 진격했나요…
# ⚠️  miss [9788961910439] 아테네 시민들은 아리스테이데스를 보고 어떤 행…
# ⚠️  miss [9788961910439] 아테네를 넘보고 있는 페르시아에 대비하기 위해…
# ⚠️  miss [9788961910439] 예술을 너무 모른다는 말을 들은 테미스토클레스…
# ⚠️  miss [9788961910439] 아테네에게 군함 20척을 도움받은 이오니아는 …
# ⚠️  miss [9788964172087] 토끼 앞엔 무엇을 놓았나요?…
# ⚠️  miss [9788964172087] 몽이는 뭐라고 말했나요?…
# ⚠️  miss [9788964172087] 어흥이는 어떤 기분이었나요?…
# ⚠️  miss [9788964172087] 토끼의 집은 어떻게 되어있나요?…
# ⚠️  miss [9788964172162] 소라가 진희에게 밉다고 하자 진희는 어떻게 했…
# ⚠️  miss [9788964172162] 소라와 진희는 어떤 말을 따라했나요?…
# ⚠️  miss [9788964172162] 두 번째로 만난 말은 무엇인가요?…
# ⚠️  miss [9788964172162] 진희가 싫다고 말해 소라는 어떻게 행동했나요?…
# ⚠️  miss [9788964172278] 형은 무엇을 보면서 비웃었었나요?…
# ⚠️  miss [9788964172308] 환한 빛을 내더니 합쳐진 것은 무엇일까요?…
# ⚠️  miss [9788964172308] 유라가 거울 조각에 글자를 써넣자 어떤 일이 …
# ⚠️  miss [9788992910828] 꼬마 나라 아이들은 어떤 씨앗을 보았나요?…
# ⚠️  miss [9788992910828] 앞으로 가! 다음 차례는 어떤 행동을 하게 하…
# ⚠️  miss [9791128202148] 도시에 많은 건 무엇일까요?…
# ⚠️  miss [9791128202148] 산골짜기에서 흘러내린 물줄기들은 어떻게 흐르나…
# ⚠️  miss [9791128202148] 바닷가 마을 사람들은 무슨 일을 하며 살아가나…
# ⚠️  miss [9791128202193] 만타루 씨네 집과 공장 주변의 나무들은 어땠나…
# ⚠️  miss [9791128202193] 수상한 씨는 만타루 씨를 어떻게 맞아 주었나요…
# ⚠️  miss [9791128202193] 수상한 씨는 신기한 것을 보여준다고 말하고서 …
# ⚠️  miss [9791128214400] 사람들이 직접 독수리를 키워서 새끼를 낳게 도…
# ⚠️  miss [9791159420245] 사자는 왜 잠에서 깨고 말았나요?…
# ⚠️  miss [899059121X] 오늘은 무슨 날인가요?…
# ⚠️  miss [9788954342292] 탑은 어디로부터 발전했나요?…
# ⚠️  miss [9788954342292] 허황옥은 어느 나라의 공주였나요?…
# ⚠️  miss [9788954342292] 남장을 하고 집을 나선 아사녀는 무엇을 넘고 …
# ⚠️  miss [9788954342292] 세계에서 가장 오래된 목판 인쇄본 무구정광대다…
# ⚠️  miss [9788954342292] 연못에 도착한 아사달은 어떻게 하였을까요?…
# ⚠️  miss [9788954342292] 사라지는 아사달을 잡으려고 아사녀는 어떻게 하…
# ⚠️  miss [9788954342292] 아사달은 왜 많은 절에서 불상이나 석탑을 만들…
# ⚠️  miss [9788963836348] 수건을 왜 챙겼나요?…
# ⚠️  miss [9788964170090] 무엇을 타 보겠냐고 물었나요?…
# ⚠️  miss [9788964170205] 마술사가 가는 곳 마다  뭐라고 말했나요?…
# ⚠️  miss [9788964170205] 요정이 뭐라고 귀띔 해주었나요?…
# ⚠️  miss [9788993877885] 물방울들은 바다 위로 어떻게 했나요?…
# ⚠️  miss [9791128216381] 모자이크는 돌이나 유리 외에 또 어떤 것으로 …
# ⚠️  miss [9791128216381] 월터 크레인이 활동한 분야는 그림과 그림책의 …
# ⚠️  miss [9791128216381] 네델란드의 대표적인 후기 인상주의 화가는 누구…
# ⚠️  miss [9791128216381] 일월오봉도의 병풍에는 해와 달과 다섯 개의 산…
# ⚠️  miss [9791128216381] 얀 페르메이르는 그린 일상적인 모습은 어떻게 …
# ⚠️  miss [9791165437367] 무엇을 하고 노나요?…
# ⚠️  miss [9791165952020] 이가 흔들리기만 하고 안 빠지는 것을 언제 알…
# ⚠️  miss [9791165952020] 이 때문에 걱정인 곰은 어떤 기분이었을까요?…
# ⚠️  miss [9791165952020] 이빨 요정에게 이를 주기 위해 셋은 무엇을 했…
# ⚠️  miss [9791165952075] 릴라는 누구에게 들켰을까요?…
# ⚠️  miss [9791165952075] 릴라를 잡은 친구는 누구인가요?…
# ⚠️  miss [9791165952075] 토미에게 산책가자고 말한 것은 누구인가요?…
# ⚠️  miss [9791165952075] 책을 더 읽어 달라고 누가 졸라댔나요?…
# ⚠️  miss [9791165952075] 토미가 마침내 (빨간 모자)를 다 듣게 된 것…
# ⚠️  miss [9791165952075] 게으른 고양이 토미는 하루 내내 무엇을 할까요…
# ⚠️  miss [9791165952075] 책들은 어디에 있나요?…
# ⚠️  miss [9791165952105] 냄새를 따라 재빠르게 뛰어 어디를 갔나요?…
# ⚠️  miss [9791157594405] 우리나라 한글을 창제한 왕은 누구인가요?…
# ⚠️  miss [9791157594405] 물물 교환 보다 물품 화계가 더 어떤가요?…
# ⚠️  miss [9791157594405] 한국조폐공사에서 만들어진 돈은 이후 어떻게 되…
# ⚠️  miss [9791157594405] 환전은 왜 해야 하나요?…
# ⚠️  miss [9791157594405] 알뜰이는 부모님 덕분에 편한 생활을 하고 있다…
# ⚠️  miss [9788968730641] 포니는 무엇을 하였나요?…
# ⚠️  miss [9788968731068] 깡총이는 혼자서 무엇을 했나요?…
# ⚠️  miss [9788927206699] 서은이 친구들이 집에 오자 누가 반겨 주었나요…
# ⚠️  miss [9788927206736] 엎드려서 보면 안 된다는 말을 들은 영철이는 …
# ⚠️  miss [9788927206743] 현준이는 강아지를 안을 때 어떤 마음으로 안았…
# ⚠️  miss [9791185721477] 현수는 아이에게 비키라고 말하자 아이는 어떤 …
# ⚠️  miss [9791185721477] 피에로는 무엇을 했나요?…
# ⚠️  miss [9791186298817] 혈소판과 하얀 장군을 보고 뭐라고 하였나요?…
# ✅ val.json — books:281  no-sub:1

# %% [markdown]
# ### validate

# %%
# ╔═══════════════╗
# ║  🟢  Cell 2   ║  상세 검증 스크립트
# ╚═══════════════╝

import json, textwrap, statistics
from pathlib import Path

def validate(split: str, root: Path = Path("./converted/formatted")):
    path = root / f"{split}.json"
    if not path.exists():
        print(f"{split}: 파일이 없습니다.")
        return
    blob = json.loads(path.read_text(encoding="utf-8"))

    art_cnt = par_cnt = qa_cnt = 0
    empty_ans = out_of_bounds = mismatch = 0
    bad_samples = []

    ctx_lengths = []
    ans_lengths = []

    for art in blob["data"]:
        art_cnt += 1
        for par in art["paragraphs"]:
            par_cnt += 1
            ctx = par["context"]
            ctx_lengths.append(len(ctx))
            for qa in par["qas"]:
                qa_cnt += 1
                if not qa["answers"]:
                    empty_ans += 1
                    bad_samples.append(("EMPTY", qa["id"], qa["question"][:40]))
                    continue
                ans = qa["answers"][0]
                text, start = ans["text"], ans["answer_start"]
                ans_lengths.append(len(text))

                if start < 0 or start + len(text) > len(ctx):
                    out_of_bounds += 1
                    bad_samples.append(("OOB", qa["id"], qa["question"][:40]))
                elif ctx[start:start + len(text)] != text:
                    mismatch += 1
                    bad_samples.append(("MISMATCH", qa["id"], qa["question"][:40]))

    print(f"\n📜 {path.name}")
    print(f"  articles        : {art_cnt}")
    print(f"  paragraphs      : {par_cnt}")
    print(f"  QAs             : {qa_cnt}")
    print(f"  ├── empty answer      : {empty_ans}")
    print(f"  ├── start OOB         : {out_of_bounds}")
    print(f"  └── substring mismatch: {mismatch}")

    if ctx_lengths:
        print(f"  context length  : max {max(ctx_lengths)}, "
              f"avg {statistics.mean(ctx_lengths):.1f}")
    if ans_lengths:
        print(f"  answer length   : max {max(ans_lengths)}, "
              f"avg {statistics.mean(ans_lengths):.1f}")

    if bad_samples:
        print("\n  ⚠️  첫 5개 오류 샘플")
        for kind, qid, qpreview in bad_samples[:5]:
            print(f"   [{kind}] {qid}  |  {qpreview}…")

# 실행
validate("train")
validate("val")
# Out:
# 📜 train.json
#   articles        : 1441
#   paragraphs      : 1441
#   QAs             : 45772
#   ├── empty answer      : 0
#   ├── start OOB         : 0
#   └── substring mismatch: 0
#   context length  : max 185806, avg 3068.3
#   answer length   : max 99, avg 6.0
#
# 📜 val.json
#   articles        : 281
#   paragraphs      : 281
#   QAs             : 5721
#   ├── empty answer      : 0
#   ├── start OOB         : 0
#   └── substring mismatch: 0
#   context length  : max 129815, avg 2430.2
#   answer length   : max 54, avg 6.1
